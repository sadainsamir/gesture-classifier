# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\sadai\mediapipe_env\lib\site-packages (21.2.3)Note: you may need to restart the kernel to use updated packages.
#
# Collecting pip
#   Downloading pip-25.0.1-py3-none-any.whl (1.8 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 21.2.3
#     Uninstalling pip-21.2.3:
#       Successfully uninstalled pip-21.2.3
# Successfully installed pip-25.0.1

# %%
# !pip install mediapipe opencv-python pandas scikit-learn
# Out:
# Collecting mediapipe
#   Using cached mediapipe-0.10.21-cp310-cp310-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: opencv-python in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (4.11.0.86)
# Requirement already satisfied: pandas in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (2.2.3)
# Requirement already satisfied: scikit-learn in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (1.6.1)
# Requirement already satisfied: absl-py in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from mediapipe) (2.2.2)
# Collecting attrs>=19.1.0 (from mediapipe)
#   Using cached attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from mediapipe) (25.2.10)
# Requirement already satisfied: jax in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from mediapipe) (0.4.30)
# Requirement already satisfied: jaxlib in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from mediapipe) (0.4.30)
# Requirement already satisfied: matplotlib in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from mediapipe) (3.10.1)
# Requirement already satisfied: numpy<2 in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from mediapipe) (1.23.5)
# Collecting opencv-contrib-python (from mediapipe)
#   Using cached opencv_contrib_python-4.11.0.86-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting protobuf<5,>=4.25.3 (from mediapipe)
#   Using cached protobuf-4.25.6-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Collecting sounddevice>=0.4.4 (from mediapipe)
#   Using cached sounddevice-0.5.1-py3-none-win_amd64.whl.metadata (1.4 kB)
# Collecting sentencepiece (from mediapipe)
#   Using cached sentencepiece-0.2.0-cp310-cp310-win_amd64.whl.metadata (8.3 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting CFFI>=1.0 (from sounddevice>=0.4.4->mediapipe)
#   Downloading cffi-1.17.1-cp310-cp310-win_amd64.whl.metadata (1.6 kB)
# Requirement already satisfied: ml-dtypes>=0.2.0 in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from jax->mediapipe) (0.5.1)
# Requirement already satisfied: opt-einsum in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from jax->mediapipe) (3.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from matplotlib->mediapipe) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from matplotlib->mediapipe) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from matplotlib->mediapipe) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from matplotlib->mediapipe) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from matplotlib->mediapipe) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from matplotlib->mediapipe) (3.2.3)
# Collecting pycparser (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe)
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Using cached mediapipe-0.10.21-cp310-cp310-win_amd64.whl (51.0 MB)
# Using cached attrs-25.3.0-py3-none-any.whl (63 kB)
# Using cached protobuf-4.25.6-cp310-abi3-win_amd64.whl (413 kB)
# Using cached sounddevice-0.5.1-py3-none-win_amd64.whl (363 kB)
# Using cached opencv_contrib_python-4.11.0.86-cp37-abi3-win_amd64.whl (46.2 MB)
# Using cached sentencepiece-0.2.0-cp310-cp310-win_amd64.whl (991 kB)
# Downloading cffi-1.17.1-cp310-cp310-win_amd64.whl (181 kB)
# Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Installing collected packages: sentencepiece, pycparser, protobuf, opencv-contrib-python, attrs, CFFI, sounddevice, mediapipe
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# Successfully installed CFFI-1.17.1 attrs-25.3.0 mediapipe-0.10.21 opencv-contrib-python-4.11.0.86 protobuf-4.25.6 pycparser-2.22 sentencepiece-0.2.0 sounddevice-0.5.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf2onnx 1.16.1 requires protobuf~=3.20, but you have protobuf 4.25.6 which is incompatible.

# %%
import mediapipe as mp # Import mediapipe
import cv2 # Import opencv
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import mediapipe as mp # Import mediapipe
#       2 import cv2 # Import opencv
#
# ModuleNotFoundError: No module named 'mediapipe'

# %%
mp_drawing = mp.solutions.drawing_utils # Drawing helpers
mp_holistic = mp.solutions.holistic # Mediapipe Solutions

# %%
import cv2
import mediapipe as mp

# Initialize MediaPipe solutions
mp_drawing = mp.solutions.drawing_utils
mp_holistic = mp.solutions.holistic
mp_face_mesh = mp.solutions.face_mesh  # ✅ Needed for face connections

# Start webcam
cap = cv2.VideoCapture(0)

# Use the holistic model
with mp_holistic.Holistic(
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5
) as holistic:

    while cap.isOpened():
        ret, frame = cap.read()

        # Convert the image color to RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False #by setting this up, you are prevent copying image data but you also able to use the same image for rendering

        # Process the image and get the result
        results = holistic.process(image)

        # Convert image back to BGR for OpenCV
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        # Draw face landmarks
        mp_drawing.draw_landmarks(
            image,
            results.face_landmarks,
            mp_face_mesh.FACEMESH_TESSELATION,
            mp_drawing.DrawingSpec(color=(80, 110, 10), thickness=1, circle_radius=1),
            mp_drawing.DrawingSpec(color=(80, 256, 121), thickness=1, circle_radius=1)
        )

        # Draw right hand landmarks
        mp_drawing.draw_landmarks(
            image,
            results.right_hand_landmarks,
            mp_holistic.HAND_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(80, 22, 10), thickness=2, circle_radius=4),
            mp_drawing.DrawingSpec(color=(80, 44, 121), thickness=2, circle_radius=2)
        )

        # Draw left hand landmarks
        mp_drawing.draw_landmarks(
            image,
            results.left_hand_landmarks,
            mp_holistic.HAND_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(121, 22, 76), thickness=2, circle_radius=4),
            mp_drawing.DrawingSpec(color=(121, 44, 250), thickness=2, circle_radius=2)
        )

        # Draw pose landmarks
        mp_drawing.draw_landmarks(
            image,
            results.pose_landmarks,
            mp_holistic.POSE_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=4),
            mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2)
        )

        # Show the image
        cv2.imshow('Raw Webcam Feed', image)

        # Break loop with 'q' key
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

# Release resources
cap.release()
cv2.destroyAllWindows()

# %%
import csv
import os
import numpy as np

# %%
num_coords = len(results.face_landmarks.landmark) + len(results.pose_landmarks.landmark)

# %%
landmarks = ['Class']
for val in range(1, num_coords+1):
    landmarks += ['x{}'.format(val), 'y{}'.format(val), 'z{}'.format(val), 'v{}'.format(val)]

# %%
landmarks
# Out:
# ['Class',
#  'x1',
#  'y1',
#  'z1',
#  'v1',
#  'x2',
#  'y2',
#  'z2',
#  'v2',
#  'x3',
#  'y3',
#  'z3',
#  'v3',
#  'x4',
#  'y4',
#  'z4',
#  'v4',
#  'x5',
#  'y5',
#  'z5',
#  'v5',
#  'x6',
#  'y6',
#  'z6',
#  'v6',
#  'x7',
#  'y7',
#  'z7',
#  'v7',
#  'x8',
#  'y8',
#  'z8',
#  'v8',
#  'x9',
#  'y9',
#  'z9',
#  'v9',
#  'x10',
#  'y10',
#  'z10',
#  'v10',
#  'x11',
#  'y11',
#  'z11',
#  'v11',
#  'x12',
#  'y12',
#  'z12',
#  'v12',
#  'x13',
#  'y13',
#  'z13',
#  'v13',
#  'x14',
#  'y14',
#  'z14',
#  'v14',
#  'x15',
#  'y15',
#  'z15',
#  'v15',
#  'x16',
#  'y16',
#  'z16',
#  'v16',
#  'x17',
#  'y17',
#  'z17',
#  'v17',
#  'x18',
#  'y18',
#  'z18',
#  'v18',
#  'x19',
#  'y19',
#  'z19',
#  'v19',
#  'x20',
#  'y20',
#  'z20',
#  'v20',
#  'x21',
#  'y21',
#  'z21',
#  'v21',
#  'x22',
#  'y22',
#  'z22',
#  'v22',
#  'x23',
#  'y23',
#  'z23',
#  'v23',
#  'x24',
#  'y24',
#  'z24',
#  'v24',
#  'x25',
#  'y25',
#  'z25',
#  'v25',
#  'x26',
#  'y26',
#  'z26',
#  'v26',
#  'x27',
#  'y27',
#  'z27',
#  'v27',
#  'x28',
#  'y28',
#  'z28',
#  'v28',
#  'x29',
#  'y29',
#  'z29',
#  'v29',
#  'x30',
#  'y30',
#  'z30',
#  'v30',
#  'x31',
#  'y31',
#  'z31',
#  'v31',
#  'x32',
#  'y32',
#  'z32',
#  'v32',
#  'x33',
#  'y33',
#  'z33',
#  'v33',
#  'x34',
#  'y34',
#  'z34',
#  'v34',
#  'x35',
#  'y35',
#  'z35',
#  'v35',
#  'x36',
#  'y36',
#  'z36',
#  'v36',
#  'x37',
#  'y37',
#  'z37',
#  'v37',
#  'x38',
#  'y38',
#  'z38',
#  'v38',
#  'x39',
#  'y39',
#  'z39',
#  'v39',
#  'x40',
#  'y40',
#  'z40',
#  'v40',
#  'x41',
#  'y41',
#  'z41',
#  'v41',
#  'x42',
#  'y42',
#  'z42',
#  'v42',
#  'x43',
#  'y43',
#  'z43',
#  'v43',
#  'x44',
#  'y44',
#  'z44',
#  'v44',
#  'x45',
#  'y45',
#  'z45',
#  'v45',
#  'x46',
#  'y46',
#  'z46',
#  'v46',
#  'x47',
#  'y47',
#  'z47',
#  'v47',
#  'x48',
#  'y48',
#  'z48',
#  'v48',
#  'x49',
#  'y49',
#  'z49',
#  'v49',
#  'x50',
#  'y50',
#  'z50',
#  'v50',
#  'x51',
#  'y51',
#  'z51',
#  'v51',
#  'x52',
#  'y52',
#  'z52',
#  'v52',
#  'x53',
#  'y53',
#  'z53',
#  'v53',
#  'x54',
#  'y54',
#  'z54',
#  'v54',
#  'x55',
#  'y55',
#  'z55',
#  'v55',
#  'x56',
#  'y56',
#  'z56',
#  'v56',
#  'x57',
#  'y57',
#  'z57',
#  'v57',
#  'x58',
#  'y58',
#  'z58',
#  'v58',
#  'x59',
#  'y59',
#  'z59',
#  'v59',
#  'x60',
#  'y60',
#  'z60',
#  'v60',
#  'x61',
#  'y61',
#  'z61',
#  'v61',
#  'x62',
#  'y62',
#  'z62',
#  'v62',
#  'x63',
#  'y63',
#  'z63',
#  'v63',
#  'x64',
#  'y64',
#  'z64',
#  'v64',
#  'x65',
#  'y65',
#  'z65',
#  'v65',
#  'x66',
#  'y66',
#  'z66',
#  'v66',
#  'x67',
#  'y67',
#  'z67',
#  'v67',
#  'x68',
#  'y68',
#  'z68',
#  'v68',
#  'x69',
#  'y69',
#  'z69',
#  'v69',
#  'x70',
#  'y70',
#  'z70',
#  'v70',
#  'x71',
#  'y71',
#  'z71',
#  'v71',
#  'x72',
#  'y72',
#  'z72',
#  'v72',
#  'x73',
#  'y73',
#  'z73',
#  'v73',
#  'x74',
#  'y74',
#  'z74',
#  'v74',
#  'x75',
#  'y75',
#  'z75',
#  'v75',
#  'x76',
#  'y76',
#  'z76',
#  'v76',
#  'x77',
#  'y77',
#  'z77',
#  'v77',
#  'x78',
#  'y78',
#  'z78',
#  'v78',
#  'x79',
#  'y79',
#  'z79',
#  'v79',
#  'x80',
#  'y80',
#  'z80',
#  'v80',
#  'x81',
#  'y81',
#  'z81',
#  'v81',
#  'x82',
#  'y82',
#  'z82',
#  'v82',
#  'x83',
#  'y83',
#  'z83',
#  'v83',
#  'x84',
#  'y84',
#  'z84',
#  'v84',
#  'x85',
#  'y85',
#  'z85',
#  'v85',
#  'x86',
#  'y86',
#  'z86',
#  'v86',
#  'x87',
#  'y87',
#  'z87',
#  'v87',
#  'x88',
#  'y88',
#  'z88',
#  'v88',
#  'x89',
#  'y89',
#  'z89',
#  'v89',
#  'x90',
#  'y90',
#  'z90',
#  'v90',
#  'x91',
#  'y91',
#  'z91',
#  'v91',
#  'x92',
#  'y92',
#  'z92',
#  'v92',
#  'x93',
#  'y93',
#  'z93',
#  'v93',
#  'x94',
#  'y94',
#  'z94',
#  'v94',
#  'x95',
#  'y95',
#  'z95',
#  'v95',
#  'x96',
#  'y96',
#  'z96',
#  'v96',
#  'x97',
#  'y97',
#  'z97',
#  'v97',
#  'x98',
#  'y98',
#  'z98',
#  'v98',
#  'x99',
#  'y99',
#  'z99',
#  'v99',
#  'x100',
#  'y100',
#  'z100',
#  'v100',
#  'x101',
#  'y101',
#  'z101',
#  'v101',
#  'x102',
#  'y102',
#  'z102',
#  'v102',
#  'x103',
#  'y103',
#  'z103',
#  'v103',
#  'x104',
#  'y104',
#  'z104',
#  'v104',
#  'x105',
#  'y105',
#  'z105',
#  'v105',
#  'x106',
#  'y106',
#  'z106',
#  'v106',
#  'x107',
#  'y107',
#  'z107',
#  'v107',
#  'x108',
#  'y108',
#  'z108',
#  'v108',
#  'x109',
#  'y109',
#  'z109',
#  'v109',
#  'x110',
#  'y110',
#  'z110',
#  'v110',
#  'x111',
#  'y111',
#  'z111',
#  'v111',
#  'x112',
#  'y112',
#  'z112',
#  'v112',
#  'x113',
#  'y113',
#  'z113',
#  'v113',
#  'x114',
#  'y114',
#  'z114',
#  'v114',
#  'x115',
#  'y115',
#  'z115',
#  'v115',
#  'x116',
#  'y116',
#  'z116',
#  'v116',
#  'x117',
#  'y117',
#  'z117',
#  'v117',
#  'x118',
#  'y118',
#  'z118',
#  'v118',
#  'x119',
#  'y119',
#  'z119',
#  'v119',
#  'x120',
#  'y120',
#  'z120',
#  'v120',
#  'x121',
#  'y121',
#  'z121',
#  'v121',
#  'x122',
#  'y122',
#  'z122',
#  'v122',
#  'x123',
#  'y123',
#  'z123',
#  'v123',
#  'x124',
#  'y124',
#  'z124',
#  'v124',
#  'x125',
#  'y125',
#  'z125',
#  'v125',
#  'x126',
#  'y126',
#  'z126',
#  'v126',
#  'x127',
#  'y127',
#  'z127',
#  'v127',
#  'x128',
#  'y128',
#  'z128',
#  'v128',
#  'x129',
#  'y129',
#  'z129',
#  'v129',
#  'x130',
#  'y130',
#  'z130',
#  'v130',
#  'x131',
#  'y131',
#  'z131',
#  'v131',
#  'x132',
#  'y132',
#  'z132',
#  'v132',
#  'x133',
#  'y133',
#  'z133',
#  'v133',
#  'x134',
#  'y134',
#  'z134',
#  'v134',
#  'x135',
#  'y135',
#  'z135',
#  'v135',
#  'x136',
#  'y136',
#  'z136',
#  'v136',
#  'x137',
#  'y137',
#  'z137',
#  'v137',
#  'x138',
#  'y138',
#  'z138',
#  'v138',
#  'x139',
#  'y139',
#  'z139',
#  'v139',
#  'x140',
#  'y140',
#  'z140',
#  'v140',
#  'x141',
#  'y141',
#  'z141',
#  'v141',
#  'x142',
#  'y142',
#  'z142',
#  'v142',
#  'x143',
#  'y143',
#  'z143',
#  'v143',
#  'x144',
#  'y144',
#  'z144',
#  'v144',
#  'x145',
#  'y145',
#  'z145',
#  'v145',
#  'x146',
#  'y146',
#  'z146',
#  'v146',
#  'x147',
#  'y147',
#  'z147',
#  'v147',
#  'x148',
#  'y148',
#  'z148',
#  'v148',
#  'x149',
#  'y149',
#  'z149',
#  'v149',
#  'x150',
#  'y150',
#  'z150',
#  'v150',
#  'x151',
#  'y151',
#  'z151',
#  'v151',
#  'x152',
#  'y152',
#  'z152',
#  'v152',
#  'x153',
#  'y153',
#  'z153',
#  'v153',
#  'x154',
#  'y154',
#  'z154',
#  'v154',
#  'x155',
#  'y155',
#  'z155',
#  'v155',
#  'x156',
#  'y156',
#  'z156',
#  'v156',
#  'x157',
#  'y157',
#  'z157',
#  'v157',
#  'x158',
#  'y158',
#  'z158',
#  'v158',
#  'x159',
#  'y159',
#  'z159',
#  'v159',
#  'x160',
#  'y160',
#  'z160',
#  'v160',
#  'x161',
#  'y161',
#  'z161',
#  'v161',
#  'x162',
#  'y162',
#  'z162',
#  'v162',
#  'x163',
#  'y163',
#  'z163',
#  'v163',
#  'x164',
#  'y164',
#  'z164',
#  'v164',
#  'x165',
#  'y165',
#  'z165',
#  'v165',
#  'x166',
#  'y166',
#  'z166',
#  'v166',
#  'x167',
#  'y167',
#  'z167',
#  'v167',
#  'x168',
#  'y168',
#  'z168',
#  'v168',
#  'x169',
#  'y169',
#  'z169',
#  'v169',
#  'x170',
#  'y170',
#  'z170',
#  'v170',
#  'x171',
#  'y171',
#  'z171',
#  'v171',
#  'x172',
#  'y172',
#  'z172',
#  'v172',
#  'x173',
#  'y173',
#  'z173',
#  'v173',
#  'x174',
#  'y174',
#  'z174',
#  'v174',
#  'x175',
#  'y175',
#  'z175',
#  'v175',
#  'x176',
#  'y176',
#  'z176',
#  'v176',
#  'x177',
#  'y177',
#  'z177',
#  'v177',
#  'x178',
#  'y178',
#  'z178',
#  'v178',
#  'x179',
#  'y179',
#  'z179',
#  'v179',
#  'x180',
#  'y180',
#  'z180',
#  'v180',
#  'x181',
#  'y181',
#  'z181',
#  'v181',
#  'x182',
#  'y182',
#  'z182',
#  'v182',
#  'x183',
#  'y183',
#  'z183',
#  'v183',
#  'x184',
#  'y184',
#  'z184',
#  'v184',
#  'x185',
#  'y185',
#  'z185',
#  'v185',
#  'x186',
#  'y186',
#  'z186',
#  'v186',
#  'x187',
#  'y187',
#  'z187',
#  'v187',
#  'x188',
#  'y188',
#  'z188',
#  'v188',
#  'x189',
#  'y189',
#  'z189',
#  'v189',
#  'x190',
#  'y190',
#  'z190',
#  'v190',
#  'x191',
#  'y191',
#  'z191',
#  'v191',
#  'x192',
#  'y192',
#  'z192',
#  'v192',
#  'x193',
#  'y193',
#  'z193',
#  'v193',
#  'x194',
#  'y194',
#  'z194',
#  'v194',
#  'x195',
#  'y195',
#  'z195',
#  'v195',
#  'x196',
#  'y196',
#  'z196',
#  'v196',
#  'x197',
#  'y197',
#  'z197',
#  'v197',
#  'x198',
#  'y198',
#  'z198',
#  'v198',
#  'x199',
#  'y199',
#  'z199',
#  'v199',
#  'x200',
#  'y200',
#  'z200',
#  'v200',
#  'x201',
#  'y201',
#  'z201',
#  'v201',
#  'x202',
#  'y202',
#  'z202',
#  'v202',
#  'x203',
#  'y203',
#  'z203',
#  'v203',
#  'x204',
#  'y204',
#  'z204',
#  'v204',
#  'x205',
#  'y205',
#  'z205',
#  'v205',
#  'x206',
#  'y206',
#  'z206',
#  'v206',
#  'x207',
#  'y207',
#  'z207',
#  'v207',
#  'x208',
#  'y208',
#  'z208',
#  'v208',
#  'x209',
#  'y209',
#  'z209',
#  'v209',
#  'x210',
#  'y210',
#  'z210',
#  'v210',
#  'x211',
#  'y211',
#  'z211',
#  'v211',
#  'x212',
#  'y212',
#  'z212',
#  'v212',
#  'x213',
#  'y213',
#  'z213',
#  'v213',
#  'x214',
#  'y214',
#  'z214',
#  'v214',
#  'x215',
#  'y215',
#  'z215',
#  'v215',
#  'x216',
#  'y216',
#  'z216',
#  'v216',
#  'x217',
#  'y217',
#  'z217',
#  'v217',
#  'x218',
#  'y218',
#  'z218',
#  'v218',
#  'x219',
#  'y219',
#  'z219',
#  'v219',
#  'x220',
#  'y220',
#  'z220',
#  'v220',
#  'x221',
#  'y221',
#  'z221',
#  'v221',
#  'x222',
#  'y222',
#  'z222',
#  'v222',
#  'x223',
#  'y223',
#  'z223',
#  'v223',
#  'x224',
#  'y224',
#  'z224',
#  'v224',
#  'x225',
#  'y225',
#  'z225',
#  'v225',
#  'x226',
#  'y226',
#  'z226',
#  'v226',
#  'x227',
#  'y227',
#  'z227',
#  'v227',
#  'x228',
#  'y228',
#  'z228',
#  'v228',
#  'x229',
#  'y229',
#  'z229',
#  'v229',
#  'x230',
#  'y230',
#  'z230',
#  'v230',
#  'x231',
#  'y231',
#  'z231',
#  'v231',
#  'x232',
#  'y232',
#  'z232',
#  'v232',
#  'x233',
#  'y233',
#  'z233',
#  'v233',
#  'x234',
#  'y234',
#  'z234',
#  'v234',
#  'x235',
#  'y235',
#  'z235',
#  'v235',
#  'x236',
#  'y236',
#  'z236',
#  'v236',
#  'x237',
#  'y237',
#  'z237',
#  'v237',
#  'x238',
#  'y238',
#  'z238',
#  'v238',
#  'x239',
#  'y239',
#  'z239',
#  'v239',
#  'x240',
#  'y240',
#  'z240',
#  'v240',
#  'x241',
#  'y241',
#  'z241',
#  'v241',
#  'x242',
#  'y242',
#  'z242',
#  'v242',
#  'x243',
#  'y243',
#  'z243',
#  'v243',
#  'x244',
#  'y244',
#  'z244',
#  'v244',
#  'x245',
#  'y245',
#  'z245',
#  'v245',
#  'x246',
#  'y246',
#  'z246',
#  'v246',
#  'x247',
#  'y247',
#  'z247',
#  'v247',
#  'x248',
#  'y248',
#  'z248',
#  'v248',
#  'x249',
#  'y249',
#  'z249',
#  'v249',
#  'x250',
#  'y250',
#  'z250',
#  ...]

# %%
with open('coords.csv', mode = 'w', newline = '') as f:
    csv_writer = csv.writer(f, delimiter = ',', quotechar = '"', quoting = csv.QUOTE_MINIMAL)
    csv_writer.writerow(landmarks)

# %%
pose = results.pose_landmarks.landmark
pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())

# %%
face = results.face_landmarks.landmark
face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())

# %%
row = pose_row+face_row

# %%
row.insert(0, class_name)

# %%
class_name = 'WAKANDA FOREVER'

# %%
import cv2
import mediapipe as mp

# Initialize MediaPipe solutions
mp_drawing = mp.solutions.drawing_utils
mp_holistic = mp.solutions.holistic
mp_face_mesh = mp.solutions.face_mesh  # ✅ Needed for face connections

# Start webcam
cap = cv2.VideoCapture(0)

# Use the holistic model
with mp_holistic.Holistic(
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5
) as holistic:

    while cap.isOpened(): 
        ret, frame = cap.read()

        # Convert the image color to RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False #by setting this up, you are prevent copying image data but you also able to use the same image for rendering

        # Process the image and get the result
        results = holistic.process(image)

        # Convert image back to BGR for OpenCV
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        # Draw face landmarks
        mp_drawing.draw_landmarks(
            image,
            results.face_landmarks,
            mp_face_mesh.FACEMESH_TESSELATION,
            mp_drawing.DrawingSpec(color=(80, 110, 10), thickness=1, circle_radius=1),
            mp_drawing.DrawingSpec(color=(80, 256, 121), thickness=1, circle_radius=1)
        )

        # Draw right hand landmarks
        mp_drawing.draw_landmarks(
            image,
            results.right_hand_landmarks,
            mp_holistic.HAND_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(80, 22, 10), thickness=2, circle_radius=4),
            mp_drawing.DrawingSpec(color=(80, 44, 121), thickness=2, circle_radius=2)
        )

        # Draw left hand landmarks
        mp_drawing.draw_landmarks(
            image,
            results.left_hand_landmarks,
            mp_holistic.HAND_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(121, 22, 76), thickness=2, circle_radius=4),
            mp_drawing.DrawingSpec(color=(121, 44, 250), thickness=2, circle_radius=2)
        )

        # Draw pose landmarks
        mp_drawing.draw_landmarks(
            image,
            results.pose_landmarks,
            mp_holistic.POSE_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=4),
            mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2)
        )

        #exporting coordinates
        try:
            #extracting pose landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())

            #extracting face LAndmarksb
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())

            #concate rows
            row = pose_row+face_row

            #appending class name
            row.insert(0, class_name)

            #export to csv
            with open('coords.csv', mode = 'a', newline = '') as f:
                csv_writer = csv.writer(f, delimiter = ',', quotechar = '"', quoting = csv.QUOTE_MINIMAL)
                csv_writer.writerow(row)
        except:
            pass

            
        # Show the image
        cv2.imshow('Raw Webcam Feed', image)

        # Break loop with 'q' key
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

# Release resources
cap.release()
cv2.destroyAllWindows()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv(r'C:\Users\sadai\mediapipe\coords.csv')

# %%
df.tail()
# Out:
#                 Class        x1        y1        z1        v1        x2  \
# 2623  WAKANDA FOREVER  0.641475  0.322840 -0.867461  0.999638  0.664070
# 2624  WAKANDA FOREVER  0.622316  0.316109 -0.894995  0.999670  0.649339
# 2625  WAKANDA FOREVER  0.608366  0.307123 -0.844727  0.999699  0.639771
# 2626  WAKANDA FOREVER  0.602627  0.303381 -0.869993  0.999725  0.635763
# 2627  WAKANDA FOREVER  0.596522  0.303809 -0.992153  0.999749  0.631561
#
#             y2        z2        v2        x3  ...      z499  v499      x500  \
# 2623  0.269244 -0.806132  0.999320  0.680480  ... -0.002011   0.0  0.680959
# 2624  0.254857 -0.830759  0.999378  0.665915  ... -0.001011   0.0  0.666522
# 2625  0.243216 -0.785220  0.999430  0.657165  ... -0.005221   0.0  0.658941
# 2626  0.238007 -0.811918  0.999477  0.653355  ... -0.005332   0.0  0.658351
# 2627  0.235659 -0.932501  0.999518  0.650332  ... -0.007093   0.0  0.659875
#
#           y500      z500  v500      x501      y501      z501  v501
# 2623  0.264216  0.016325   0.0  0.685706  0.260479  0.016850   0.0
# 2624  0.246919  0.018271   0.0  0.671637  0.242273  0.018855   0.0
# 2625  0.234340  0.014880   0.0  0.664376  0.229320  0.015385   0.0
# 2626  0.233369  0.014574   0.0  0.664010  0.228562  0.015013   0.0
# 2627  0.230641  0.014191   0.0  0.665643  0.225612  0.014603   0.0
#
# [5 rows x 2005 columns]

# %%
df[df['Class']  =='Sad']
# Out:
#     Class        x1        y1        z1        v1        x2        y2  \
# 323   Sad  0.564193  0.501370 -1.599780  0.994514  0.606734  0.418128
# 324   Sad  0.563877  0.504212 -1.614065  0.994748  0.606759  0.418875
# 325   Sad  0.563608  0.505851 -1.625767  0.994867  0.606663  0.419240
# 326   Sad  0.563602  0.507850 -1.667452  0.994951  0.606722  0.419974
# 327   Sad  0.563545  0.509127 -1.672019  0.995201  0.606693  0.420189
# ..    ...       ...       ...       ...       ...       ...       ...
# 747   Sad  0.623043  0.511552 -1.606375  0.998374  0.660112  0.426755
# 748   Sad  0.622920  0.511359 -1.640693  0.998404  0.659928  0.426680
# 749   Sad  0.622821  0.511384 -1.599539  0.998425  0.659801  0.426918
# 750   Sad  0.622744  0.511299 -1.558027  0.998423  0.659701  0.426911
# 751   Sad  0.622792  0.511759 -1.535467  0.998463  0.659582  0.427478
#
#            z2        v2        x3  ...      z499  v499      x500      y500  \
# 323 -1.449841  0.995516  0.633829  ...  0.009362   0.0  0.651788  0.423691
# 324 -1.477744  0.995739  0.633865  ...  0.008936   0.0  0.653294  0.425375
# 325 -1.492001  0.995887  0.633570  ...  0.008534   0.0  0.654208  0.424249
# 326 -1.528705  0.995996  0.633554  ...  0.008796   0.0  0.652020  0.421636
# 327 -1.534538  0.996207  0.633327  ...  0.008289   0.0  0.652132  0.421522
# ..        ...       ...       ...  ...       ...   ...       ...       ...
# 747 -1.482224  0.998146  0.683705  ...  0.000453   0.0  0.694585  0.423539
# 748 -1.511465  0.998183  0.683538  ...  0.000825   0.0  0.694737  0.424229
# 749 -1.476166  0.998222  0.683403  ...  0.000884   0.0  0.696322  0.423954
# 750 -1.434096  0.998248  0.683301  ...  0.000938   0.0  0.695618  0.425004
# 751 -1.407652  0.998325  0.683177  ...  0.000959   0.0  0.695198  0.424159
#
#          z500  v500      x501      y501      z501  v501
# 323  0.036663   0.0  0.659996  0.415406  0.038080   0.0
# 324  0.035602   0.0  0.661471  0.418122  0.036799   0.0
# 325  0.035398   0.0  0.662414  0.416863  0.036620   0.0
# 326  0.035480   0.0  0.660126  0.414752  0.036632   0.0
# 327  0.034743   0.0  0.660230  0.414240  0.035898   0.0
# ..        ...   ...       ...       ...       ...   ...
# 747  0.026464   0.0  0.701300  0.418333  0.027292   0.0
# 748  0.027282   0.0  0.701414  0.418813  0.028219   0.0
# 749  0.027022   0.0  0.703012  0.418685  0.027883   0.0
# 750  0.026972   0.0  0.702318  0.419769  0.027891   0.0
# 751  0.026972   0.0  0.701851  0.418826  0.027877   0.0
#
# [429 rows x 2005 columns]

# %%
x = df.drop('Class', axis = 1) #features
y = df['Class'] #target value

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 1234)

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
pipelines = {
        'lr': make_pipeline(StandardScaler(), LogisticRegression(max_iter=1000)),
        'rc':make_pipeline(StandardScaler(), RidgeClassifier()),
        'rf':make_pipeline(StandardScaler(), RandomForestClassifier()),
        'gb':make_pipeline(StandardScaler(), GradientBoostingClassifier()),    
}

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model = pipeline.fit(x_train, y_train)
    fit_models[algo] = model

# %%
fit_models
# Out:
# {'lr': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression', LogisticRegression(max_iter=1000))]),
#  'rc': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('ridgeclassifier', RidgeClassifier())]),
#  'rf': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier', RandomForestClassifier())]),
#  'gb': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('gradientboostingclassifier', GradientBoostingClassifier())])}

# %%
fit_models['rc'].predict(x_test)
# Out:
# array(['WAKANDA FOREVER', 'Talking On Phone', 'WAKANDA FOREVER',
#        'Namaste Beta', 'Thumbs_up', 'Sad', 'Talking On Phone', 'Sad',
#        'Thumbs_up', 'Namaste Beta', 'Namaste Beta', 'WAKANDA FOREVER',
#        'Namaste Beta', 'Talking On Phone', 'Happy', 'Talking On Phone',
#        'Sad', 'Namaste Beta', 'Happy', 'WAKANDA FOREVER', 'Namaste Beta',
#        'Sad', 'Thumbs_up', 'WAKANDA FOREVER', 'Sad', 'Thumbs_up', 'Sad',
#        'Happy', 'Namaste Beta', 'Happy', 'Sad', 'WAKANDA FOREVER',
#        'Talking On Phone', 'Sad', 'Namaste Beta', 'Happy', 'Sad', 'Happy',
#        'Thumbs_up', 'Sad', 'Happy', 'Sad', 'Talking On Phone', 'Happy',
#        'Sad', 'Thumbs_up', 'Sad', 'Happy', 'Happy', 'Talking On Phone',
#        'Sad', 'WAKANDA FOREVER', 'Talking On Phone', 'Sad',
#        'Namaste Beta', 'WAKANDA FOREVER', 'Talking On Phone', 'Happy',
#        'WAKANDA FOREVER', 'WAKANDA FOREVER', 'WAKANDA FOREVER',
#        'Talking On Phone', 'Thumbs_up', 'Happy', 'Talking On Phone',
#        'Sad', 'Thumbs_up', 'Sad', 'Talking On Phone', 'Sad',
#        'WAKANDA FOREVER', 'Namaste Beta', 'Namaste Beta', 'Happy',
#        'Happy', 'Namaste Beta', 'WAKANDA FOREVER', 'WAKANDA FOREVER',
#        'Sad', 'Namaste Beta', 'Happy', 'Thumbs_up', 'Namaste Beta',
#        'WAKANDA FOREVER', 'Namaste Beta', 'Namaste Beta', 'Namaste Beta',
#        'Namaste Beta', 'WAKANDA FOREVER', 'Namaste Beta',
#        'Talking On Phone', 'WAKANDA FOREVER', 'Happy', 'Namaste Beta',
#        'Happy', 'Thumbs_up', 'WAKANDA FOREVER', 'Thumbs_up',
#        'Namaste Beta', 'Namaste Beta', 'WAKANDA FOREVER',
#        'WAKANDA FOREVER', 'Thumbs_up', 'Namaste Beta', 'Namaste Beta',
#        'Talking On Phone', 'WAKANDA FOREVER', 'WAKANDA FOREVER',
#        'Namaste Beta', 'WAKANDA FOREVER', 'Sad', 'Namaste Beta', 'Sad',
#        'Sad', 'Namaste Beta', 'Talking On Phone', 'Namaste Beta', 'Happy',
#        'Thumbs_up', 'WAKANDA FOREVER', 'Namaste Beta', 'WAKANDA FOREVER',
#        'Namaste Beta', 'Namaste Beta', 'WAKANDA FOREVER', 'Sad', 'Happy',
#        'WAKANDA FOREVER', 'Sad', 'Happy', 'Sad', 'Sad', 'Sad', 'Happy',
#        'Thumbs_up', 'WAKANDA FOREVER', 'Sad', 'Happy', 'Happy',
#        'WAKANDA FOREVER', 'WAKANDA FOREVER', 'Sad', 'Sad',
#        'WAKANDA FOREVER', 'WAKANDA FOREVER', 'Happy', 'Happy',
#        'Namaste Beta', 'WAKANDA FOREVER', 'Sad', 'Namaste Beta',
#        'WAKANDA FOREVER', 'WAKANDA FOREVER', 'Sad', 'WAKANDA FOREVER',
#        'WAKANDA FOREVER', 'WAKANDA FOREVER', 'Namaste Beta',
#        'Talking On Phone', 'WAKANDA FOREVER', 'Namaste Beta',
#        'WAKANDA FOREVER', 'WAKANDA FOREVER', 'Talking On Phone', 'Sad',
#        'Happy', 'Talking On Phone', 'Namaste Beta', 'Namaste Beta',
#        'Happy', 'Happy', 'Happy', 'Talking On Phone', 'Happy',
#        'Thumbs_up', 'Namaste Beta', 'Namaste Beta', 'Namaste Beta',
#        'Namaste Beta', 'WAKANDA FOREVER', 'Sad', 'Thumbs_up',
#        'Talking On Phone', 'Namaste Beta', 'Namaste Beta', 'Happy',
#        'Namaste Beta', 'Happy', 'Talking On Phone', 'Sad',
#        'Talking On Phone', 'Talking On Phone', 'WAKANDA FOREVER',
#        'Thumbs_up', 'Talking On Phone', 'Talking On Phone',
#        'Talking On Phone', 'Namaste Beta', 'Thumbs_up',
#        'Talking On Phone', 'Namaste Beta', 'Talking On Phone',
#        'Namaste Beta', 'Sad', 'Namaste Beta', 'Namaste Beta', 'Sad',
#        'Happy', 'Namaste Beta', 'Talking On Phone', 'Happy', 'Happy',
#        'Happy', 'Namaste Beta', 'Happy', 'WAKANDA FOREVER',
#        'WAKANDA FOREVER', 'Happy', 'Talking On Phone', 'WAKANDA FOREVER',
#        'Namaste Beta', 'WAKANDA FOREVER', 'Namaste Beta', 'Namaste Beta',
#        'Happy', 'Sad', 'Namaste Beta', 'Talking On Phone', 'Sad',
#        'WAKANDA FOREVER', 'Namaste Beta', 'WAKANDA FOREVER',
#        'WAKANDA FOREVER', 'Talking On Phone', 'Happy', 'Namaste Beta',
#        'WAKANDA FOREVER', 'Namaste Beta', 'WAKANDA FOREVER',
#        'WAKANDA FOREVER', 'Namaste Beta', 'Sad', 'Happy',
#        'Talking On Phone', 'Namaste Beta', 'Thumbs_up', 'Happy', 'Happy',
#        'WAKANDA FOREVER', 'Namaste Beta', 'Talking On Phone', 'Sad',
#        'Sad', 'WAKANDA FOREVER', 'Namaste Beta', 'WAKANDA FOREVER',
#        'Namaste Beta', 'Namaste Beta', 'WAKANDA FOREVER',
#        'WAKANDA FOREVER', 'Namaste Beta', 'Happy', 'Talking On Phone',
#        'Talking On Phone', 'Namaste Beta', 'Talking On Phone',
#        'Namaste Beta', 'WAKANDA FOREVER', 'Talking On Phone', 'Sad',
#        'Talking On Phone', 'WAKANDA FOREVER', 'WAKANDA FOREVER',
#        'WAKANDA FOREVER', 'Happy', 'Talking On Phone', 'WAKANDA FOREVER',
#        'Thumbs_up', 'Sad', 'Sad', 'Happy', 'WAKANDA FOREVER',
#        'Namaste Beta', 'Namaste Beta', 'Namaste Beta', 'Sad', 'Sad',
#        'Sad', 'Talking On Phone', 'Namaste Beta', 'WAKANDA FOREVER',
#        'Talking On Phone', 'WAKANDA FOREVER', 'Sad', 'WAKANDA FOREVER',
#        'Talking On Phone', 'Sad', 'Talking On Phone', 'Happy',
#        'Namaste Beta', 'Talking On Phone', 'WAKANDA FOREVER', 'Happy',
#        'WAKANDA FOREVER', 'Talking On Phone', 'Namaste Beta',
#        'Namaste Beta', 'WAKANDA FOREVER', 'Sad', 'Namaste Beta',
#        'Talking On Phone', 'Talking On Phone', 'Happy', 'Namaste Beta',
#        'Thumbs_up', 'Talking On Phone', 'Namaste Beta', 'WAKANDA FOREVER',
#        'Thumbs_up', 'WAKANDA FOREVER', 'Sad', 'Thumbs_up', 'Namaste Beta',
#        'Happy', 'WAKANDA FOREVER', 'Thumbs_up', 'WAKANDA FOREVER',
#        'WAKANDA FOREVER', 'Talking On Phone', 'Namaste Beta',
#        'WAKANDA FOREVER', 'Talking On Phone', 'WAKANDA FOREVER',
#        'Namaste Beta', 'Sad', 'Sad', 'Thumbs_up', 'WAKANDA FOREVER',
#        'Thumbs_up', 'WAKANDA FOREVER', 'WAKANDA FOREVER',
#        'WAKANDA FOREVER', 'Sad', 'Namaste Beta', 'Namaste Beta',
#        'Talking On Phone', 'Talking On Phone', 'Sad', 'Happy', 'Happy',
#        'Namaste Beta', 'Happy', 'Happy', 'Talking On Phone',
#        'WAKANDA FOREVER', 'Happy', 'Thumbs_up', 'WAKANDA FOREVER',
#        'WAKANDA FOREVER', 'Sad', 'Happy', 'Sad', 'WAKANDA FOREVER',
#        'Happy', 'WAKANDA FOREVER', 'Namaste Beta', 'WAKANDA FOREVER',
#        'Talking On Phone', 'Namaste Beta', 'Namaste Beta', 'Namaste Beta',
#        'Namaste Beta', 'Talking On Phone', 'Namaste Beta', 'Sad', 'Happy',
#        'Talking On Phone', 'Talking On Phone', 'Namaste Beta',
#        'Talking On Phone', 'Happy', 'Happy', 'WAKANDA FOREVER', 'Sad',
#        'Talking On Phone', 'Thumbs_up', 'Namaste Beta', 'Sad',
#        'WAKANDA FOREVER', 'Happy', 'Talking On Phone', 'WAKANDA FOREVER',
#        'Namaste Beta', 'Sad', 'WAKANDA FOREVER', 'Sad', 'Happy', 'Sad',
#        'Namaste Beta', 'WAKANDA FOREVER', 'WAKANDA FOREVER', 'Sad',
#        'Namaste Beta', 'WAKANDA FOREVER', 'Sad', 'Namaste Beta',
#        'WAKANDA FOREVER', 'Sad', 'Sad', 'WAKANDA FOREVER', 'Namaste Beta',
#        'WAKANDA FOREVER', 'Namaste Beta', 'Namaste Beta', 'Namaste Beta',
#        'Happy', 'WAKANDA FOREVER', 'WAKANDA FOREVER', 'WAKANDA FOREVER',
#        'Happy', 'WAKANDA FOREVER', 'Namaste Beta', 'Thumbs_up',
#        'Thumbs_up', 'Namaste Beta', 'WAKANDA FOREVER', 'WAKANDA FOREVER',
#        'Sad', 'Namaste Beta', 'WAKANDA FOREVER', 'Thumbs_up',
#        'Namaste Beta', 'Happy', 'WAKANDA FOREVER', 'Sad', 'Thumbs_up',
#        'WAKANDA FOREVER', 'Talking On Phone', 'Namaste Beta', 'Happy',
#        'WAKANDA FOREVER', 'Namaste Beta', 'Thumbs_up', 'Namaste Beta',
#        'Talking On Phone', 'WAKANDA FOREVER', 'Happy', 'Talking On Phone',
#        'Namaste Beta', 'Talking On Phone', 'Sad', 'Talking On Phone',
#        'WAKANDA FOREVER', 'Thumbs_up', 'Happy', 'Talking On Phone', 'Sad',
#        'Namaste Beta', 'WAKANDA FOREVER', 'Thumbs_up', 'Happy',
#        'Thumbs_up', 'WAKANDA FOREVER', 'Thumbs_up', 'Sad', 'Namaste Beta',
#        'Talking On Phone', 'Sad', 'Happy', 'Sad', 'Sad',
#        'WAKANDA FOREVER', 'Talking On Phone', 'Namaste Beta',
#        'WAKANDA FOREVER', 'Sad', 'Namaste Beta', 'Talking On Phone',
#        'Thumbs_up', 'Namaste Beta', 'Talking On Phone', 'WAKANDA FOREVER',
#        'Happy', 'Sad', 'WAKANDA FOREVER', 'Sad', 'Sad', 'Sad',
#        'WAKANDA FOREVER', 'Sad', 'WAKANDA FOREVER', 'Namaste Beta',
#        'WAKANDA FOREVER', 'Namaste Beta', 'Happy', 'Talking On Phone',
#        'Namaste Beta', 'Sad', 'Thumbs_up', 'Sad', 'Thumbs_up',
#        'WAKANDA FOREVER', 'WAKANDA FOREVER', 'Sad', 'Talking On Phone',
#        'WAKANDA FOREVER', 'Sad', 'Namaste Beta', 'Namaste Beta', 'Sad',
#        'Namaste Beta', 'Talking On Phone', 'Thumbs_up', 'Sad',
#        'Talking On Phone', 'Thumbs_up', 'Talking On Phone', 'Sad', 'Sad',
#        'Happy', 'Namaste Beta', 'Namaste Beta', 'Namaste Beta', 'Happy',
#        'WAKANDA FOREVER', 'WAKANDA FOREVER', 'WAKANDA FOREVER', 'Happy',
#        'WAKANDA FOREVER', 'Sad', 'Thumbs_up', 'Happy', 'Talking On Phone',
#        'Happy', 'Namaste Beta', 'WAKANDA FOREVER', 'WAKANDA FOREVER',
#        'Namaste Beta', 'Talking On Phone', 'Talking On Phone',
#        'WAKANDA FOREVER', 'Happy', 'Sad', 'Talking On Phone',
#        'WAKANDA FOREVER', 'Happy', 'Sad', 'Talking On Phone', 'Happy',
#        'Talking On Phone', 'Namaste Beta', 'Talking On Phone',
#        'Thumbs_up', 'WAKANDA FOREVER', 'Thumbs_up', 'Talking On Phone',
#        'WAKANDA FOREVER', 'Sad', 'Talking On Phone', 'Namaste Beta',
#        'Namaste Beta', 'WAKANDA FOREVER', 'Happy', 'Talking On Phone',
#        'Namaste Beta', 'Thumbs_up', 'Sad', 'Happy', 'Namaste Beta', 'Sad',
#        'Happy', 'WAKANDA FOREVER', 'Namaste Beta', 'Namaste Beta',
#        'Happy', 'Happy', 'Sad', 'WAKANDA FOREVER', 'WAKANDA FOREVER',
#        'Thumbs_up', 'Namaste Beta', 'Namaste Beta', 'Namaste Beta',
#        'WAKANDA FOREVER', 'WAKANDA FOREVER', 'WAKANDA FOREVER', 'Happy',
#        'Sad', 'Talking On Phone', 'Namaste Beta', 'Talking On Phone',
#        'WAKANDA FOREVER', 'Sad', 'Happy', 'Talking On Phone', 'Sad',
#        'Happy', 'Sad', 'Happy', 'Thumbs_up', 'Happy', 'Happy',
#        'Namaste Beta', 'Namaste Beta', 'Namaste Beta', 'WAKANDA FOREVER',
#        'Namaste Beta', 'Namaste Beta', 'WAKANDA FOREVER', 'Namaste Beta',
#        'Namaste Beta', 'Thumbs_up', 'Sad', 'Talking On Phone', 'Sad',
#        'Talking On Phone', 'Namaste Beta', 'Thumbs_up', 'Namaste Beta',
#        'Talking On Phone', 'WAKANDA FOREVER', 'Happy', 'Happy',
#        'WAKANDA FOREVER', 'Thumbs_up', 'WAKANDA FOREVER', 'Happy',
#        'Namaste Beta', 'Sad', 'WAKANDA FOREVER', 'Sad',
#        'Talking On Phone', 'Talking On Phone', 'Sad', 'Sad',
#        'Talking On Phone', 'Namaste Beta', 'Namaste Beta', 'Happy',
#        'Talking On Phone', 'Namaste Beta', 'Sad', 'Thumbs_up',
#        'Thumbs_up', 'Namaste Beta', 'Sad', 'Sad', 'Namaste Beta',
#        'Talking On Phone', 'WAKANDA FOREVER', 'Happy', 'WAKANDA FOREVER',
#        'Namaste Beta', 'Namaste Beta', 'Namaste Beta', 'Talking On Phone',
#        'WAKANDA FOREVER', 'WAKANDA FOREVER', 'Sad', 'Namaste Beta',
#        'Thumbs_up', 'Namaste Beta', 'Sad', 'WAKANDA FOREVER', 'Sad',
#        'Sad', 'WAKANDA FOREVER', 'Talking On Phone', 'Happy',
#        'Namaste Beta', 'Talking On Phone', 'Sad', 'WAKANDA FOREVER',
#        'Namaste Beta', 'Happy', 'Talking On Phone', 'WAKANDA FOREVER',
#        'Talking On Phone', 'WAKANDA FOREVER', 'WAKANDA FOREVER',
#        'Talking On Phone', 'Talking On Phone', 'Talking On Phone',
#        'Namaste Beta', 'Sad', 'Talking On Phone', 'Namaste Beta',
#        'Talking On Phone', 'Sad', 'Sad', 'Sad', 'Namaste Beta',
#        'Thumbs_up', 'WAKANDA FOREVER', 'Sad', 'Happy', 'WAKANDA FOREVER',
#        'WAKANDA FOREVER', 'Namaste Beta', 'WAKANDA FOREVER',
#        'WAKANDA FOREVER', 'Thumbs_up', 'Sad', 'Thumbs_up',
#        'WAKANDA FOREVER', 'WAKANDA FOREVER', 'Talking On Phone',
#        'WAKANDA FOREVER', 'WAKANDA FOREVER', 'WAKANDA FOREVER',
#        'Namaste Beta', 'Thumbs_up', 'Namaste Beta', 'Sad',
#        'WAKANDA FOREVER', 'WAKANDA FOREVER', 'WAKANDA FOREVER',
#        'Talking On Phone', 'Thumbs_up', 'Namaste Beta', 'Happy',
#        'Namaste Beta', 'Sad', 'Namaste Beta', 'Happy', 'WAKANDA FOREVER',
#        'Namaste Beta', 'WAKANDA FOREVER', 'Talking On Phone',
#        'WAKANDA FOREVER', 'WAKANDA FOREVER', 'Thumbs_up',
#        'WAKANDA FOREVER', 'WAKANDA FOREVER', 'Namaste Beta', 'Thumbs_up',
#        'Talking On Phone', 'Talking On Phone', 'Namaste Beta',
#        'Talking On Phone', 'Happy', 'Talking On Phone', 'WAKANDA FOREVER',
#        'Happy', 'Sad', 'Thumbs_up', 'Namaste Beta', 'WAKANDA FOREVER',
#        'WAKANDA FOREVER', 'Sad', 'Sad', 'Sad', 'Sad', 'Thumbs_up',
#        'Talking On Phone', 'WAKANDA FOREVER', 'Sad', 'WAKANDA FOREVER',
#        'WAKANDA FOREVER', 'Namaste Beta', 'WAKANDA FOREVER',
#        'WAKANDA FOREVER', 'Happy', 'WAKANDA FOREVER', 'WAKANDA FOREVER',
#        'WAKANDA FOREVER', 'Thumbs_up', 'Sad', 'Thumbs_up', 'Happy',
#        'Thumbs_up', 'Sad', 'Talking On Phone', 'Sad', 'Sad',
#        'WAKANDA FOREVER', 'Talking On Phone', 'Namaste Beta', 'Happy',
#        'Namaste Beta', 'Sad', 'Namaste Beta', 'Talking On Phone',
#        'Namaste Beta', 'Happy', 'Namaste Beta', 'Happy', 'Sad',
#        'Namaste Beta'], dtype='<U16')

# %%
from sklearn.metrics import accuracy_score #accuracy metrics
import pickle

# %%
for algo, model in fit_models.items():
    yhat = model.predict(x_test)
    print(algo, accuracy_score(y_test, yhat))
# Out:
# lr 0.9961977186311787
# rc 0.9885931558935361
# rf 0.9936628643852978
# gb 0.9961977186311787

# %%
fit_models['lr'].predict(x_test)
# Out:
# array(['WAKANDA FOREVER', 'Talking On Phone', 'WAKANDA FOREVER',
#        'Namaste Beta', 'Thumbs_up', 'Sad', 'Talking On Phone', 'Sad',
#        'Thumbs_up', 'Namaste Beta', 'Namaste Beta', 'WAKANDA FOREVER',
#        'Namaste Beta', 'Talking On Phone', 'Happy', 'Talking On Phone',
#        'Sad', 'Namaste Beta', 'Happy', 'WAKANDA FOREVER', 'Namaste Beta',
#        'Sad', 'Thumbs_up', 'WAKANDA FOREVER', 'Sad', 'Thumbs_up', 'Sad',
#        'Happy', 'Namaste Beta', 'Happy', 'Sad', 'WAKANDA FOREVER',
#        'Talking On Phone', 'Sad', 'Namaste Beta', 'Happy', 'Sad', 'Happy',
#        'Thumbs_up', 'Sad', 'Happy', 'Sad', 'Talking On Phone', 'Happy',
#        'Sad', 'Thumbs_up', 'Sad', 'Thumbs_up', 'Happy',
#        'Talking On Phone', 'Sad', 'WAKANDA FOREVER', 'Talking On Phone',
#        'Sad', 'Namaste Beta', 'WAKANDA FOREVER', 'Talking On Phone',
#        'Happy', 'WAKANDA FOREVER', 'WAKANDA FOREVER', 'WAKANDA FOREVER',
#        'Talking On Phone', 'Thumbs_up', 'Happy', 'Talking On Phone',
#        'Sad', 'Thumbs_up', 'Sad', 'Talking On Phone', 'Sad',
#        'WAKANDA FOREVER', 'Namaste Beta', 'Namaste Beta', 'Happy',
#        'Happy', 'Namaste Beta', 'WAKANDA FOREVER', 'WAKANDA FOREVER',
#        'Sad', 'Namaste Beta', 'Happy', 'Thumbs_up', 'Namaste Beta',
#        'WAKANDA FOREVER', 'Namaste Beta', 'Namaste Beta', 'Namaste Beta',
#        'Namaste Beta', 'WAKANDA FOREVER', 'Namaste Beta',
#        'Talking On Phone', 'WAKANDA FOREVER', 'Happy', 'Namaste Beta',
#        'Happy', 'Thumbs_up', 'WAKANDA FOREVER', 'Thumbs_up',
#        'Namaste Beta', 'Namaste Beta', 'WAKANDA FOREVER',
#        'WAKANDA FOREVER', 'Thumbs_up', 'Namaste Beta', 'Namaste Beta',
#        'Talking On Phone', 'WAKANDA FOREVER', 'WAKANDA FOREVER',
#        'Namaste Beta', 'WAKANDA FOREVER', 'Sad', 'Namaste Beta', 'Sad',
#        'Sad', 'Namaste Beta', 'Talking On Phone', 'Namaste Beta', 'Happy',
#        'Thumbs_up', 'WAKANDA FOREVER', 'Namaste Beta', 'WAKANDA FOREVER',
#        'Namaste Beta', 'Namaste Beta', 'WAKANDA FOREVER', 'Sad', 'Happy',
#        'WAKANDA FOREVER', 'Sad', 'Happy', 'Sad', 'Sad', 'Sad', 'Happy',
#        'Thumbs_up', 'WAKANDA FOREVER', 'Sad', 'Happy', 'Happy',
#        'WAKANDA FOREVER', 'WAKANDA FOREVER', 'Sad', 'Sad',
#        'WAKANDA FOREVER', 'WAKANDA FOREVER', 'Happy', 'Happy',
#        'Namaste Beta', 'WAKANDA FOREVER', 'Sad', 'Namaste Beta',
#        'WAKANDA FOREVER', 'WAKANDA FOREVER', 'Sad', 'WAKANDA FOREVER',
#        'WAKANDA FOREVER', 'WAKANDA FOREVER', 'Namaste Beta',
#        'Talking On Phone', 'WAKANDA FOREVER', 'Namaste Beta',
#        'WAKANDA FOREVER', 'WAKANDA FOREVER', 'Talking On Phone', 'Sad',
#        'Happy', 'Talking On Phone', 'Namaste Beta', 'Namaste Beta',
#        'Happy', 'Happy', 'Happy', 'Talking On Phone', 'Happy',
#        'Thumbs_up', 'Namaste Beta', 'Namaste Beta', 'Namaste Beta',
#        'Namaste Beta', 'WAKANDA FOREVER', 'Sad', 'Thumbs_up',
#        'Talking On Phone', 'Namaste Beta', 'Namaste Beta', 'Happy',
#        'Namaste Beta', 'Happy', 'Talking On Phone', 'Sad',
#        'Talking On Phone', 'Talking On Phone', 'WAKANDA FOREVER',
#        'Thumbs_up', 'Talking On Phone', 'Talking On Phone',
#        'Talking On Phone', 'Namaste Beta', 'Thumbs_up',
#        'Talking On Phone', 'Namaste Beta', 'Talking On Phone',
#        'Namaste Beta', 'Sad', 'Namaste Beta', 'Namaste Beta', 'Sad',
#        'Happy', 'Namaste Beta', 'Talking On Phone', 'Happy', 'Happy',
#        'Happy', 'Namaste Beta', 'Happy', 'WAKANDA FOREVER',
#        'WAKANDA FOREVER', 'Happy', 'Talking On Phone', 'WAKANDA FOREVER',
#        'Namaste Beta', 'WAKANDA FOREVER', 'Namaste Beta', 'Namaste Beta',
#        'Happy', 'Sad', 'Namaste Beta', 'Talking On Phone', 'Sad',
#        'WAKANDA FOREVER', 'Namaste Beta', 'WAKANDA FOREVER',
#        'WAKANDA FOREVER', 'Talking On Phone', 'Happy', 'Namaste Beta',
#        'WAKANDA FOREVER', 'Namaste Beta', 'WAKANDA FOREVER',
#        'WAKANDA FOREVER', 'Namaste Beta', 'Sad', 'Happy',
#        'Talking On Phone', 'Namaste Beta', 'Thumbs_up', 'Happy', 'Happy',
#        'WAKANDA FOREVER', 'Namaste Beta', 'Talking On Phone', 'Sad',
#        'Sad', 'WAKANDA FOREVER', 'Namaste Beta', 'WAKANDA FOREVER',
#        'Namaste Beta', 'Namaste Beta', 'WAKANDA FOREVER',
#        'WAKANDA FOREVER', 'Namaste Beta', 'Happy', 'Talking On Phone',
#        'Talking On Phone', 'Namaste Beta', 'Talking On Phone',
#        'Namaste Beta', 'WAKANDA FOREVER', 'Talking On Phone', 'Sad',
#        'Talking On Phone', 'WAKANDA FOREVER', 'WAKANDA FOREVER',
#        'WAKANDA FOREVER', 'Happy', 'Talking On Phone', 'WAKANDA FOREVER',
#        'Thumbs_up', 'Sad', 'Sad', 'Happy', 'WAKANDA FOREVER',
#        'Namaste Beta', 'Namaste Beta', 'Namaste Beta', 'Sad', 'Sad',
#        'Sad', 'Talking On Phone', 'Namaste Beta', 'WAKANDA FOREVER',
#        'Talking On Phone', 'WAKANDA FOREVER', 'Sad', 'WAKANDA FOREVER',
#        'Talking On Phone', 'Sad', 'Talking On Phone', 'Happy',
#        'Namaste Beta', 'Talking On Phone', 'WAKANDA FOREVER', 'Happy',
#        'WAKANDA FOREVER', 'Talking On Phone', 'Namaste Beta',
#        'Namaste Beta', 'WAKANDA FOREVER', 'Sad', 'Namaste Beta',
#        'Talking On Phone', 'Talking On Phone', 'Happy', 'Namaste Beta',
#        'Thumbs_up', 'Talking On Phone', 'Namaste Beta', 'WAKANDA FOREVER',
#        'Thumbs_up', 'WAKANDA FOREVER', 'Sad', 'Thumbs_up', 'Namaste Beta',
#        'Happy', 'WAKANDA FOREVER', 'Thumbs_up', 'WAKANDA FOREVER',
#        'WAKANDA FOREVER', 'Talking On Phone', 'Namaste Beta',
#        'WAKANDA FOREVER', 'Talking On Phone', 'WAKANDA FOREVER',
#        'Namaste Beta', 'Sad', 'Sad', 'Thumbs_up', 'WAKANDA FOREVER',
#        'Thumbs_up', 'WAKANDA FOREVER', 'WAKANDA FOREVER',
#        'WAKANDA FOREVER', 'Sad', 'Thumbs_up', 'Namaste Beta',
#        'Talking On Phone', 'Talking On Phone', 'Sad', 'Happy', 'Happy',
#        'Namaste Beta', 'Happy', 'Happy', 'Talking On Phone',
#        'WAKANDA FOREVER', 'Happy', 'Thumbs_up', 'WAKANDA FOREVER',
#        'WAKANDA FOREVER', 'Sad', 'Happy', 'Sad', 'WAKANDA FOREVER',
#        'Happy', 'WAKANDA FOREVER', 'Namaste Beta', 'WAKANDA FOREVER',
#        'Talking On Phone', 'Namaste Beta', 'Namaste Beta', 'Namaste Beta',
#        'Namaste Beta', 'Talking On Phone', 'Namaste Beta', 'Sad', 'Happy',
#        'Talking On Phone', 'Talking On Phone', 'Namaste Beta',
#        'Talking On Phone', 'Happy', 'Happy', 'WAKANDA FOREVER', 'Sad',
#        'Talking On Phone', 'Thumbs_up', 'Namaste Beta', 'Sad',
#        'WAKANDA FOREVER', 'Happy', 'Talking On Phone', 'WAKANDA FOREVER',
#        'Namaste Beta', 'Sad', 'WAKANDA FOREVER', 'Sad', 'Happy', 'Sad',
#        'Namaste Beta', 'WAKANDA FOREVER', 'WAKANDA FOREVER', 'Sad',
#        'Namaste Beta', 'WAKANDA FOREVER', 'Sad', 'Namaste Beta',
#        'WAKANDA FOREVER', 'Sad', 'Sad', 'WAKANDA FOREVER', 'Namaste Beta',
#        'WAKANDA FOREVER', 'Thumbs_up', 'Namaste Beta', 'Namaste Beta',
#        'Happy', 'WAKANDA FOREVER', 'WAKANDA FOREVER', 'WAKANDA FOREVER',
#        'Happy', 'WAKANDA FOREVER', 'Namaste Beta', 'Namaste Beta',
#        'Thumbs_up', 'Namaste Beta', 'WAKANDA FOREVER', 'WAKANDA FOREVER',
#        'Sad', 'Namaste Beta', 'WAKANDA FOREVER', 'Thumbs_up',
#        'Namaste Beta', 'Happy', 'WAKANDA FOREVER', 'Sad', 'Thumbs_up',
#        'WAKANDA FOREVER', 'Talking On Phone', 'Namaste Beta', 'Happy',
#        'WAKANDA FOREVER', 'Thumbs_up', 'Thumbs_up', 'Namaste Beta',
#        'Talking On Phone', 'WAKANDA FOREVER', 'Happy', 'Talking On Phone',
#        'Namaste Beta', 'Talking On Phone', 'Sad', 'Talking On Phone',
#        'WAKANDA FOREVER', 'Thumbs_up', 'Happy', 'Talking On Phone', 'Sad',
#        'Namaste Beta', 'WAKANDA FOREVER', 'Thumbs_up', 'Happy',
#        'Thumbs_up', 'WAKANDA FOREVER', 'Thumbs_up', 'Sad', 'Namaste Beta',
#        'Talking On Phone', 'Sad', 'Happy', 'Sad', 'Sad',
#        'WAKANDA FOREVER', 'Talking On Phone', 'Namaste Beta',
#        'WAKANDA FOREVER', 'Sad', 'Namaste Beta', 'Talking On Phone',
#        'Thumbs_up', 'Namaste Beta', 'Talking On Phone', 'WAKANDA FOREVER',
#        'Happy', 'Sad', 'WAKANDA FOREVER', 'Sad', 'Sad', 'Sad',
#        'WAKANDA FOREVER', 'Sad', 'WAKANDA FOREVER', 'Namaste Beta',
#        'WAKANDA FOREVER', 'Namaste Beta', 'Happy', 'Talking On Phone',
#        'Namaste Beta', 'Sad', 'Thumbs_up', 'Sad', 'Thumbs_up',
#        'WAKANDA FOREVER', 'WAKANDA FOREVER', 'Sad', 'Talking On Phone',
#        'WAKANDA FOREVER', 'Sad', 'Namaste Beta', 'Namaste Beta', 'Sad',
#        'Namaste Beta', 'Talking On Phone', 'Thumbs_up', 'Sad',
#        'Talking On Phone', 'Thumbs_up', 'Talking On Phone', 'Sad', 'Sad',
#        'Happy', 'Namaste Beta', 'Namaste Beta', 'Namaste Beta', 'Happy',
#        'WAKANDA FOREVER', 'WAKANDA FOREVER', 'WAKANDA FOREVER', 'Happy',
#        'WAKANDA FOREVER', 'Sad', 'Thumbs_up', 'Happy', 'Talking On Phone',
#        'Happy', 'Thumbs_up', 'WAKANDA FOREVER', 'WAKANDA FOREVER',
#        'Namaste Beta', 'Talking On Phone', 'Talking On Phone',
#        'WAKANDA FOREVER', 'Happy', 'Sad', 'Talking On Phone',
#        'WAKANDA FOREVER', 'Happy', 'Sad', 'Talking On Phone', 'Happy',
#        'Talking On Phone', 'Namaste Beta', 'Talking On Phone',
#        'Thumbs_up', 'WAKANDA FOREVER', 'Thumbs_up', 'Talking On Phone',
#        'WAKANDA FOREVER', 'Sad', 'Talking On Phone', 'Namaste Beta',
#        'Namaste Beta', 'WAKANDA FOREVER', 'Happy', 'Talking On Phone',
#        'Namaste Beta', 'Thumbs_up', 'Sad', 'Happy', 'Namaste Beta', 'Sad',
#        'Happy', 'WAKANDA FOREVER', 'Namaste Beta', 'Namaste Beta',
#        'Happy', 'Happy', 'Sad', 'WAKANDA FOREVER', 'WAKANDA FOREVER',
#        'Thumbs_up', 'Namaste Beta', 'Namaste Beta', 'Namaste Beta',
#        'WAKANDA FOREVER', 'WAKANDA FOREVER', 'WAKANDA FOREVER', 'Happy',
#        'Sad', 'Talking On Phone', 'Namaste Beta', 'Talking On Phone',
#        'WAKANDA FOREVER', 'Sad', 'Happy', 'Talking On Phone', 'Sad',
#        'Happy', 'Sad', 'Happy', 'Thumbs_up', 'Happy', 'Happy',
#        'Namaste Beta', 'Namaste Beta', 'Namaste Beta', 'WAKANDA FOREVER',
#        'Namaste Beta', 'Namaste Beta', 'WAKANDA FOREVER', 'Namaste Beta',
#        'Namaste Beta', 'Thumbs_up', 'Sad', 'Talking On Phone', 'Sad',
#        'Talking On Phone', 'Namaste Beta', 'Thumbs_up', 'Namaste Beta',
#        'Talking On Phone', 'WAKANDA FOREVER', 'Happy', 'Happy',
#        'WAKANDA FOREVER', 'Thumbs_up', 'WAKANDA FOREVER', 'Happy',
#        'Namaste Beta', 'Sad', 'WAKANDA FOREVER', 'Sad',
#        'Talking On Phone', 'Talking On Phone', 'Sad', 'Sad',
#        'Talking On Phone', 'Namaste Beta', 'Namaste Beta', 'Happy',
#        'Talking On Phone', 'Namaste Beta', 'Sad', 'Thumbs_up',
#        'Thumbs_up', 'Namaste Beta', 'Sad', 'Sad', 'Namaste Beta',
#        'Talking On Phone', 'WAKANDA FOREVER', 'Happy', 'WAKANDA FOREVER',
#        'Namaste Beta', 'Namaste Beta', 'Namaste Beta', 'Talking On Phone',
#        'WAKANDA FOREVER', 'WAKANDA FOREVER', 'Sad', 'Namaste Beta',
#        'Thumbs_up', 'Namaste Beta', 'Sad', 'WAKANDA FOREVER', 'Sad',
#        'Sad', 'WAKANDA FOREVER', 'Talking On Phone', 'Happy',
#        'Namaste Beta', 'Talking On Phone', 'Sad', 'WAKANDA FOREVER',
#        'Namaste Beta', 'Happy', 'Talking On Phone', 'WAKANDA FOREVER',
#        'Talking On Phone', 'WAKANDA FOREVER', 'WAKANDA FOREVER',
#        'Talking On Phone', 'Talking On Phone', 'Talking On Phone',
#        'Namaste Beta', 'Sad', 'Talking On Phone', 'Namaste Beta',
#        'Talking On Phone', 'Sad', 'Sad', 'Sad', 'Namaste Beta',
#        'Thumbs_up', 'WAKANDA FOREVER', 'Sad', 'Happy', 'WAKANDA FOREVER',
#        'WAKANDA FOREVER', 'Namaste Beta', 'WAKANDA FOREVER',
#        'WAKANDA FOREVER', 'Thumbs_up', 'Sad', 'Thumbs_up',
#        'WAKANDA FOREVER', 'WAKANDA FOREVER', 'Talking On Phone',
#        'WAKANDA FOREVER', 'WAKANDA FOREVER', 'WAKANDA FOREVER',
#        'Namaste Beta', 'Thumbs_up', 'Namaste Beta', 'Sad',
#        'WAKANDA FOREVER', 'WAKANDA FOREVER', 'WAKANDA FOREVER',
#        'Talking On Phone', 'Thumbs_up', 'Namaste Beta', 'Happy',
#        'Namaste Beta', 'Sad', 'Namaste Beta', 'Happy', 'WAKANDA FOREVER',
#        'Namaste Beta', 'WAKANDA FOREVER', 'Talking On Phone',
#        'WAKANDA FOREVER', 'WAKANDA FOREVER', 'Thumbs_up',
#        'WAKANDA FOREVER', 'WAKANDA FOREVER', 'Namaste Beta', 'Thumbs_up',
#        'Talking On Phone', 'Talking On Phone', 'Namaste Beta',
#        'Talking On Phone', 'Happy', 'Talking On Phone', 'WAKANDA FOREVER',
#        'Happy', 'Sad', 'Thumbs_up', 'Namaste Beta', 'WAKANDA FOREVER',
#        'WAKANDA FOREVER', 'Sad', 'Sad', 'Sad', 'Sad', 'Thumbs_up',
#        'Talking On Phone', 'WAKANDA FOREVER', 'Sad', 'WAKANDA FOREVER',
#        'WAKANDA FOREVER', 'Namaste Beta', 'WAKANDA FOREVER',
#        'WAKANDA FOREVER', 'Happy', 'WAKANDA FOREVER', 'WAKANDA FOREVER',
#        'WAKANDA FOREVER', 'Thumbs_up', 'Sad', 'Thumbs_up', 'Happy',
#        'Thumbs_up', 'Sad', 'Talking On Phone', 'Sad', 'Sad',
#        'WAKANDA FOREVER', 'Talking On Phone', 'Namaste Beta', 'Happy',
#        'Namaste Beta', 'Sad', 'Namaste Beta', 'Talking On Phone',
#        'Namaste Beta', 'Happy', 'Namaste Beta', 'Happy', 'Sad',
#        'Namaste Beta'], dtype=object)

# %%
with open('pose_detection.pkl', 'wb') as f:
    pickle.dump(fit_models['lr'], f)

# %%
y_test
# Out:
# 2616     WAKANDA FOREVER
# 1674    Talking On Phone
# 2365     WAKANDA FOREVER
# 1504        Namaste Beta
# 884            Thumbs_up
#               ...
# 124                Happy
# 1185        Namaste Beta
# 88                 Happy
# 622                  Sad
# 1148        Namaste Beta
# Name: Class, Length: 789, dtype: object

# %%
#importing the model

# %%
with open('pose_detection.pkl', 'rb') as f: #readbinary
    model = pickle.load(f)

# %%
model
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('logisticregression', LogisticRegression(max_iter=1000))])

# %%
import cv2
import mediapipe as mp

# Initialize MediaPipe solutions
mp_drawing = mp.solutions.drawing_utils
mp_holistic = mp.solutions.holistic
mp_face_mesh = mp.solutions.face_mesh  # ✅ Needed for face connections

# Start webcam
cap = cv2.VideoCapture(0)

# Use the holistic model
with mp_holistic.Holistic(
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5
) as holistic:

    while cap.isOpened(): 
        ret, frame = cap.read()

        # Convert the image color to RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False #by setting this up, you are prevent copying image data but you also able to use the same image for rendering

        # Process the image and get the result
        results = holistic.process(image)

        # Convert image back to BGR for OpenCV
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        # Draw face landmarks
        mp_drawing.draw_landmarks(
            image,
            results.face_landmarks,
            mp_face_mesh.FACEMESH_TESSELATION,
            mp_drawing.DrawingSpec(color=(80, 110, 10), thickness=1, circle_radius=1),
            mp_drawing.DrawingSpec(color=(80, 256, 121), thickness=1, circle_radius=1)
        )

        # Draw right hand landmarks
        mp_drawing.draw_landmarks(
            image,
            results.right_hand_landmarks,
            mp_holistic.HAND_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(80, 22, 10), thickness=2, circle_radius=4),
            mp_drawing.DrawingSpec(color=(80, 44, 121), thickness=2, circle_radius=2)
        )

        # Draw left hand landmarks
        mp_drawing.draw_landmarks(
            image,
            results.left_hand_landmarks,
            mp_holistic.HAND_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(121, 22, 76), thickness=2, circle_radius=4),
            mp_drawing.DrawingSpec(color=(121, 44, 250), thickness=2, circle_radius=2)
        )

        # Draw pose landmarks
        mp_drawing.draw_landmarks(
            image,
            results.pose_landmarks,
            mp_holistic.POSE_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=4),
            mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2)
        )

        #exporting coordinates
        try:
            #extracting pose landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())

            #extracting face LAndmarksb
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())

            #concate rows
            row = pose_row+face_row

            #appending class name
            # row.insert(0, class_name)

            # #export to csv
            # with open('coords.csv', mode = 'a', newline = '') as f:
            #     csv_writer = csv.writer(f, delimiter = ',', quotechar = '"', quoting = csv.QUOTE_MINIMAL)
            #     csv_writer.writerow(row)
            x = pd.DataFrame([row])
            body_language_class = model.predict(x)[0]
            body_language_prob = model.predict_proba(x)[0]
            print(body_language_class, body_language_prob)

            #grab ear coords
            coords = tuple(np.multiply(
                            np.array(
                                (results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
                                 results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y))
                        , [640,480]).astype(int))
            cv2.rectangle(image, 
                          (coords[0], coords[1]+5), 
                          (coords[0]+len(body_language_class)*20, coords[1]-30), 
                          (245, 117, 16), -1)
            
            cv2.putText(image, body_language_class, coords, 
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Get status box
            cv2.rectangle(image, (0,0), (250, 60), (245, 117, 16), -1)
            
            # Display Class
            cv2.putText(image, 'CLASS'
                        , (95,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, body_language_class.split(' ')[0]
                        , (90,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Display Probability
            cv2.putText(image, 'PROB'
                        , (15,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, str(round(body_language_prob[np.argmax(body_language_prob)],2))
                        , (10,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        except:
            pass

            
        # Show the image
        cv2.imshow('Raw Webcam Feed', image)

        # Break loop with 'q' key
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

# Release resources
cap.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# WAKANDA FOREVER [1.31763068e-06 2.33300218e-06 2.87859790e-06 3.47234022e-02
#  4.74870022e-05 9.65222582e-01]
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Namaste Beta [1.65298280e-05 4.80347059e-01 1.91422015e-02 3.83886894e-01
#  1.15860993e-01 7.46323045e-04]
# Talking On Phone [0.00053645 0.17323031 0.21257023 0.29694565 0.26439238 0.05232498]
# WAKANDA FOREVER [0.00072048 0.26540025 0.03461109 0.08189356 0.11181445 0.50556017]
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# WAKANDA FOREVER [3.24042068e-04 1.48540025e-01 7.83297673e-03 1.89240289e-02
#  1.82133047e-01 6.42245880e-01]
# WAKANDA FOREVER [2.37532576e-04 4.75457510e-02 7.94382748e-03 1.45859798e-02
#  1.25732988e-01 8.03953921e-01]
# WAKANDA FOREVER [4.59617194e-04 1.61131261e-01 3.88571253e-02 5.27554294e-02
#  2.82362541e-01 4.64434026e-01]
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# WAKANDA FOREVER [4.34148928e-04 1.36307231e-01 3.13866671e-02 2.59959180e-02
#  2.52979812e-01 5.52896223e-01]
# WAKANDA FOREVER [4.05561559e-04 2.81789979e-01 3.16107619e-02 2.82153517e-02
#  2.38745688e-01 4.19232658e-01]
# Thumbs_up [0.00051397 0.28828062 0.031679   0.02578147 0.38483923 0.26890571]
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# WAKANDA FOREVER [0.00052705 0.19476623 0.034016   0.03780314 0.35957645 0.37331112]
# WAKANDA FOREVER [0.00063397 0.21574862 0.01844521 0.01845446 0.30834913 0.43836862]
# WAKANDA FOREVER [0.00077934 0.20302979 0.00648269 0.01074234 0.25102777 0.52793807]
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Talking On Phone [0.00181214 0.02540085 0.00523395 0.83564251 0.06313344 0.06877713]
# Talking On Phone [0.00406146 0.05351625 0.00820974 0.74662779 0.11557539 0.07200938]
# Talking On Phone [0.00702847 0.124045   0.01225546 0.6725623  0.15586556 0.02824322]
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Talking On Phone [0.00717483 0.11047931 0.01160911 0.70970615 0.12235298 0.03867761]
# Talking On Phone [0.00479467 0.08361444 0.01519635 0.7429248  0.11504338 0.03842637]
# Talking On Phone [0.00179396 0.05051418 0.00733109 0.85607714 0.066259   0.01802462]
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Talking On Phone [7.68555628e-04 7.34538298e-03 2.83206666e-03 9.34090137e-01
#  3.83897855e-02 1.65740720e-02]
# Talking On Phone [0.00097376 0.00359659 0.0025713  0.93293392 0.03439793 0.0255265 ]
# Talking On Phone [3.46290277e-04 3.81479562e-04 1.44271079e-03 9.31941690e-01
#  1.39315015e-02 5.19563280e-02]
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Talking On Phone [5.36987625e-04 1.03658298e-04 2.22188171e-03 6.32044623e-01
#  1.08557571e-02 3.54237093e-01]
# Talking On Phone [4.33079027e-03 4.81004579e-04 4.30268818e-03 8.09921774e-01
#  1.90747804e-02 1.61888963e-01]
# Talking On Phone [0.00540934 0.0048327  0.0193389  0.74533832 0.11647293 0.10860782]
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Talking On Phone [0.00659918 0.00574232 0.02225654 0.69849387 0.19724116 0.06966693]
# Talking On Phone [0.00409414 0.00933648 0.06900404 0.51689667 0.24815771 0.15251096]
# Talking On Phone [0.00305148 0.00696507 0.06627309 0.46644797 0.12782391 0.32943848]
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Talking On Phone [0.00151717 0.00430522 0.05351218 0.46001178 0.02323305 0.4574206 ]
# WAKANDA FOREVER [3.74050670e-04 2.21183921e-04 2.22200591e-02 3.14683331e-01
#  1.14751549e-03 6.61353860e-01]

# %%
import cv2
import mediapipe as mp
import numpy as np
import pandas as pd
from datetime import datetime

# Initialize MediaPipe solutions
mp_drawing = mp.solutions.drawing_utils
mp_holistic = mp.solutions.holistic
mp_face_mesh = mp.solutions.face_mesh  # ✅ Needed for face connections

# Start webcam
cap = cv2.VideoCapture(0)

# Define codec and create VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter('output_with_gestures_final.mp4', fourcc, 20.0, (640, 480))

# Load your model
import pickle
with open('pose_detection.pkl', 'rb') as f:
    model = pickle.load(f)

# Use the holistic model
with mp_holistic.Holistic(
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5
) as holistic:

    while cap.isOpened(): 
        ret, frame = cap.read()
        if not ret:
            break

        # Convert the image color to RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False

        # Process the image and get the result
        results = holistic.process(image)

        # Convert image back to BGR for OpenCV
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        # Draw all landmarks
        mp_drawing.draw_landmarks(
            image, results.face_landmarks, mp_face_mesh.FACEMESH_TESSELATION,
            mp_drawing.DrawingSpec(color=(80, 110, 10), thickness=1, circle_radius=1),
            mp_drawing.DrawingSpec(color=(80, 256, 121), thickness=1, circle_radius=1)
        )

        mp_drawing.draw_landmarks(
            image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(80, 22, 10), thickness=2, circle_radius=4),
            mp_drawing.DrawingSpec(color=(80, 44, 121), thickness=2, circle_radius=2)
        )

        mp_drawing.draw_landmarks(
            image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(121, 22, 76), thickness=2, circle_radius=4),
            mp_drawing.DrawingSpec(color=(121, 44, 250), thickness=2, circle_radius=2)
        )

        mp_drawing.draw_landmarks(
            image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=4),
            mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2)
        )

        # Exporting coordinates
        try:
            # Extract pose and face landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[lm.x, lm.y, lm.z, lm.visibility] for lm in pose]).flatten())

            face = results.face_landmarks.landmark
            face_row = list(np.array([[lm.x, lm.y, lm.z, lm.visibility] for lm in face]).flatten())

            # Combine rows
            row = pose_row + face_row
            x = pd.DataFrame([row])
            body_language_class = model.predict(x)[0]
            body_language_prob = model.predict_proba(x)[0]

            # Grab coords for annotation
            coords = tuple(np.multiply(
                np.array((
                    results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x,
                    results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y
                )), [640, 480]).astype(int))

            # Draw rectangle and text
            cv2.rectangle(image, (coords[0], coords[1] + 5), 
                          (coords[0] + len(body_language_class) * 20, coords[1] - 30),
                          (245, 117, 16), -1)
            cv2.putText(image, body_language_class, coords, 
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

            # Display Class and Probability box
            cv2.rectangle(image, (0, 0), (300, 60), (245, 117, 16), -1)
            cv2.putText(image, 'CLASS', (95, 12), cv2.FONT_HERSHEY_SIMPLEX, 
                        0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, body_language_class.split(' ')[0], (90, 40), 
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

            cv2.putText(image, 'PROB', (15, 12), cv2.FONT_HERSHEY_SIMPLEX, 
                        0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, str(round(body_language_prob[np.argmax(body_language_prob)], 2)), 
                        (10, 40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

            # Add timestamp
            timestamp = datetime.now().strftime('%H:%M:%S')
            cv2.putText(image, f'Time: {timestamp}', (400, 30), 
                        cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 0), 2, cv2.LINE_AA)

        except:
            pass

        # Save current frame to output video
        out.write(image)

        # Show the image
        cv2.imshow('Raw Webcam Feed', image)

        # Break loop with 'q' key
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

# Release resources
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# ...
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\sadai\mediapipe_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint

# Load data
df = pd.read_csv('coords.csv')
X = df.drop('Class', axis=1)
y = df['Class']

# Encode target
le = LabelEncoder()
y_encoded = le.fit_transform(y)
y_categorical = to_categorical(y_encoded)

# Save the label encoder for decoding later
import pickle
with open('body_language.pkl', 'wb') as f:
    pickle.dump(le, f)

# Train/Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y_categorical, test_size=0.2, random_state=42)

# Define model
model = Sequential()
model.add(Dense(128, activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dense(64, activation='relu'))
model.add(Dense(y_categorical.shape[1], activation='softmax'))

# Compile
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train and save best model as .h5
checkpoint = ModelCheckpoint('pose_classifier.h5', monitor='val_accuracy', save_best_only=True, mode='max')
model.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test), callbacks=[checkpoint])
# Out:
# Epoch 1/50
# 66/66 [==============================] - 3s 17ms/step - loss: 1.2011 - accuracy: 0.5937 - val_loss: 0.8796 - val_accuracy: 0.7110
# Epoch 2/50
# 66/66 [==============================] - 1s 9ms/step - loss: 0.7048 - accuracy: 0.7488 - val_loss: 0.7213 - val_accuracy: 0.6787
# Epoch 3/50
# 66/66 [==============================] - 1s 8ms/step - loss: 0.5833 - accuracy: 0.7750 - val_loss: 0.6841 - val_accuracy: 0.6958
# Epoch 4/50
# 66/66 [==============================] - 1s 10ms/step - loss: 0.4898 - accuracy: 0.8130 - val_loss: 0.4264 - val_accuracy: 0.8536
# Epoch 5/50
# 66/66 [==============================] - 1s 10ms/step - loss: 0.4007 - accuracy: 0.8582 - val_loss: 0.3898 - val_accuracy: 0.8650
# Epoch 6/50
# 66/66 [==============================] - 1s 9ms/step - loss: 0.3414 - accuracy: 0.8925 - val_loss: 0.3260 - val_accuracy: 0.8840
# Epoch 7/50
# 66/66 [==============================] - 1s 8ms/step - loss: 0.3288 - accuracy: 0.8825 - val_loss: 0.3305 - val_accuracy: 0.8631
# Epoch 8/50
# 66/66 [==============================] - 1s 9ms/step - loss: 0.2759 - accuracy: 0.8949 - val_loss: 0.2889 - val_accuracy: 0.8764
# Epoch 9/50
# 66/66 [==============================] - 1s 9ms/step - loss: 0.2608 - accuracy: 0.9020 - val_loss: 0.3031 - val_accuracy: 0.8555
# Epoch 10/50
# 66/66 [==============================] - 1s 10ms/step - loss: 0.2492 - accuracy: 0.9172 - val_loss: 0.2293 - val_accuracy: 0.9240
# Epoch 11/50
# 66/66 [==============================] - 1s 10ms/step - loss: 0.2170 - accuracy: 0.9163 - val_loss: 0.1838 - val_accuracy: 0.9506
# Epoch 12/50
# 66/66 [==============================] - 1s 9ms/step - loss: 0.1789 - accuracy: 0.9396 - val_loss: 0.1836 - val_accuracy: 0.9278
# Epoch 13/50
# 66/66 [==============================] - 1s 9ms/step - loss: 0.1781 - accuracy: 0.9396 - val_loss: 0.2479 - val_accuracy: 0.8973
# Epoch 14/50
# 66/66 [==============================] - 1s 9ms/step - loss: 0.1576 - accuracy: 0.9486 - val_loss: 0.1727 - val_accuracy: 0.9278
# Epoch 15/50
# 66/66 [==============================] - 1s 10ms/step - loss: 0.1522 - accuracy: 0.9481 - val_loss: 0.1251 - val_accuracy: 0.9582
# Epoch 16/50
# 66/66 [==============================] - 1s 9ms/step - loss: 0.1353 - accuracy: 0.9553 - val_loss: 0.1841 - val_accuracy: 0.9354
# Epoch 17/50
# 66/66 [==============================] - 1s 10ms/step - loss: 0.1811 - accuracy: 0.9244 - val_loss: 0.1054 - val_accuracy: 0.9753
# Epoch 18/50
# 66/66 [==============================] - 1s 9ms/step - loss: 0.1354 - accuracy: 0.9496 - val_loss: 0.1447 - val_accuracy: 0.9411
# Epoch 19/50
# 66/66 [==============================] - 1s 9ms/step - loss: 0.1380 - accuracy: 0.9505 - val_loss: 0.1738 - val_accuracy: 0.9297
# Epoch 20/50
# 66/66 [==============================] - 1s 9ms/step - loss: 0.1216 - accuracy: 0.9605 - val_loss: 0.1309 - val_accuracy: 0.9487
# Epoch 21/50
# 66/66 [==============================] - 1s 9ms/step - loss: 0.1322 - accuracy: 0.9553 - val_loss: 0.1185 - val_accuracy: 0.9677
# Epoch 22/50
# 66/66 [==============================] - 1s 9ms/step - loss: 0.1067 - accuracy: 0.9648 - val_loss: 0.1189 - val_accuracy: 0.9506
# Epoch 23/50
# 66/66 [==============================] - 1s 10ms/step - loss: 0.1027 - accuracy: 0.9648 - val_loss: 0.0731 - val_accuracy: 0.9848
# Epoch 24/50
# 66/66 [==============================] - 1s 9ms/step - loss: 0.1117 - accuracy: 0.9600 - val_loss: 0.2046 - val_accuracy: 0.8992
# Epoch 25/50
# 66/66 [==============================] - 1s 9ms/step - loss: 0.1024 - accuracy: 0.9615 - val_loss: 0.1017 - val_accuracy: 0.9449
# Epoch 26/50
# 66/66 [==============================] - 1s 10ms/step - loss: 0.1096 - accuracy: 0.9600 - val_loss: 0.0639 - val_accuracy: 0.9886
# Epoch 27/50
# 66/66 [==============================] - 1s 8ms/step - loss: 0.0950 - accuracy: 0.9667 - val_loss: 0.0970 - val_accuracy: 0.9601
# Epoch 28/50
# 66/66 [==============================] - 1s 8ms/step - loss: 0.0976 - accuracy: 0.9715 - val_loss: 0.0662 - val_accuracy: 0.9734
# Epoch 29/50
# 66/66 [==============================] - 1s 8ms/step - loss: 0.0843 - accuracy: 0.9676 - val_loss: 0.0570 - val_accuracy: 0.9810
# Epoch 30/50
# 66/66 [==============================] - 1s 9ms/step - loss: 0.1084 - accuracy: 0.9543 - val_loss: 0.0785 - val_accuracy: 0.9791
# Epoch 31/50
# 66/66 [==============================] - 1s 10ms/step - loss: 0.0865 - accuracy: 0.9662 - val_loss: 0.0517 - val_accuracy: 0.9905
# Epoch 32/50
# 66/66 [==============================] - 1s 9ms/step - loss: 0.0645 - accuracy: 0.9810 - val_loss: 0.0842 - val_accuracy: 0.9620
# Epoch 33/50
# 66/66 [==============================] - 1s 8ms/step - loss: 0.0686 - accuracy: 0.9767 - val_loss: 0.0873 - val_accuracy: 0.9601
# Epoch 34/50
# 66/66 [==============================] - 1s 9ms/step - loss: 0.0674 - accuracy: 0.9795 - val_loss: 0.0982 - val_accuracy: 0.9639
# Epoch 35/50
# 66/66 [==============================] - 1s 9ms/step - loss: 0.0735 - accuracy: 0.9738 - val_loss: 0.0605 - val_accuracy: 0.9772
# Epoch 36/50
# 66/66 [==============================] - 1s 9ms/step - loss: 0.0671 - accuracy: 0.9772 - val_loss: 0.0455 - val_accuracy: 0.9886
# Epoch 37/50
# 66/66 [==============================] - 1s 9ms/step - loss: 0.0809 - accuracy: 0.9743 - val_loss: 0.0561 - val_accuracy: 0.9848
# Epoch 38/50
# 66/66 [==============================] - 1s 9ms/step - loss: 0.0504 - accuracy: 0.9819 - val_loss: 0.0343 - val_accuracy: 0.9924
# Epoch 39/50
# 66/66 [==============================] - 1s 9ms/step - loss: 0.0500 - accuracy: 0.9805 - val_loss: 0.0870 - val_accuracy: 0.9582
# Epoch 40/50
# 66/66 [==============================] - 1s 9ms/step - loss: 0.0603 - accuracy: 0.9800 - val_loss: 0.0705 - val_accuracy: 0.9715
# Epoch 41/50
# 66/66 [==============================] - 1s 9ms/step - loss: 0.0677 - accuracy: 0.9762 - val_loss: 0.1159 - val_accuracy: 0.9544
# Epoch 42/50
# 66/66 [==============================] - 1s 10ms/step - loss: 0.0498 - accuracy: 0.9810 - val_loss: 0.0393 - val_accuracy: 0.9943
# Epoch 43/50
# 66/66 [==============================] - 1s 9ms/step - loss: 0.0349 - accuracy: 0.9910 - val_loss: 0.0520 - val_accuracy: 0.9848
# Epoch 44/50
# 66/66 [==============================] - 1s 9ms/step - loss: 0.0683 - accuracy: 0.9762 - val_loss: 0.1140 - val_accuracy: 0.9544
# Epoch 45/50
# 66/66 [==============================] - 1s 8ms/step - loss: 0.0538 - accuracy: 0.9829 - val_loss: 0.0383 - val_accuracy: 0.9867
# Epoch 46/50
# 66/66 [==============================] - 1s 9ms/step - loss: 0.0483 - accuracy: 0.9814 - val_loss: 0.0390 - val_accuracy: 0.9867
# Epoch 47/50
# 66/66 [==============================] - 1s 9ms/step - loss: 0.0330 - accuracy: 0.9891 - val_loss: 0.0391 - val_accuracy: 0.9848
# Epoch 48/50
# 66/66 [==============================] - 1s 10ms/step - loss: 0.0310 - accuracy: 0.9914 - val_loss: 0.0225 - val_accuracy: 0.9962
# Epoch 49/50
# 66/66 [==============================] - 1s 9ms/step - loss: 0.0235 - accuracy: 0.9943 - val_loss: 0.0610 - val_accuracy: 0.9810
# Epoch 50/50
# 66/66 [==============================] - 1s 9ms/step - loss: 0.0679 - accuracy: 0.9743 - val_loss: 0.2002 - val_accuracy: 0.9049

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.12.0

# %%
pip install tf2onnx
# Out:
# Collecting tf2onnx
#   Downloading tf2onnx-1.16.1-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: numpy>=1.14.1 in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from tf2onnx) (1.23.5)
# Collecting onnx>=1.4.1 (from tf2onnx)
#   Downloading onnx-1.17.0-cp310-cp310-win_amd64.whl.metadata (16 kB)
# Requirement already satisfied: requests in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from tf2onnx) (2.32.3)
# Requirement already satisfied: six in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from tf2onnx) (1.17.0)
# Requirement already satisfied: flatbuffers>=1.12 in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from tf2onnx) (25.2.10)
# Collecting protobuf~=3.20 (from tf2onnx)
#   Downloading protobuf-3.20.3-cp310-cp310-win_amd64.whl.metadata (698 bytes)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from requests->tf2onnx) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from requests->tf2onnx) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from requests->tf2onnx) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from requests->tf2onnx) (2025.1.31)
# Downloading tf2onnx-1.16.1-py3-none-any.whl (455 kB)
# Downloading onnx-1.17.0-cp310-cp310-win_amd64.whl (14.5 MB)
#    ---------------------------------------- 0.0/14.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/14.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/14.5 MB 1.0 MB/s eta 0:00:14
#    - -------------------------------------- 0.5/14.5 MB 1.0 MB/s eta 0:00:14
#    -- ------------------------------------- 0.8/14.5 MB 763.2 kB/s eta 0:00:19
#    -- ------------------------------------- 0.8/14.5 MB 763.2 kB/s eta 0:00:19
# Note: you may need to restart the kernel to use updated packages.   -- ------------------------------------- 1.0/14.5 MB 740.5 kB/s eta 0:00:19
#
#    -- ------------------------------------- 1.0/14.5 MB 740.5 kB/s eta 0:00:19
#    --- ------------------------------------ 1.3/14.5 MB 762.6 kB/s eta 0:00:18
#    ---- ----------------------------------- 1.6/14.5 MB 806.6 kB/s eta 0:00:17
#    ----- ---------------------------------- 1.8/14.5 MB 846.1 kB/s eta 0:00:16
#    ----- ---------------------------------- 2.1/14.5 MB 863.5 kB/s eta 0:00:15
#    ----- ---------------------------------- 2.1/14.5 MB 863.5 kB/s eta 0:00:15
#    ------ --------------------------------- 2.4/14.5 MB 871.6 kB/s eta 0:00:14
#    ------- -------------------------------- 2.6/14.5 MB 915.2 kB/s eta 0:00:14
#    ------- -------------------------------- 2.6/14.5 MB 915.2 kB/s eta 0:00:14
#    ------- -------------------------------- 2.6/14.5 MB 915.2 kB/s eta 0:00:14
#    ------- -------------------------------- 2.6/14.5 MB 915.2 kB/s eta 0:00:14
#    ------- -------------------------------- 2.6/14.5 MB 915.2 kB/s eta 0:00:14
#    ------- -------------------------------- 2.9/14.5 MB 699.0 kB/s eta 0:00:17
#    ------- -------------------------------- 2.9/14.5 MB 699.0 kB/s eta 0:00:17
#    ------- -------------------------------- 2.9/14.5 MB 699.0 kB/s eta 0:00:17
#    ------- -------------------------------- 2.9/14.5 MB 699.0 kB/s eta 0:00:17
#    ------- -------------------------------- 2.9/14.5 MB 699.0 kB/s eta 0:00:17
#    -------- ------------------------------- 3.1/14.5 MB 615.2 kB/s eta 0:00:19
#    -------- ------------------------------- 3.1/14.5 MB 615.2 kB/s eta 0:00:19
#    --------- ------------------------------ 3.4/14.5 MB 606.5 kB/s eta 0:00:19
#    ---------- ----------------------------- 3
3 kB/s eta 0:00:06
#    ----------------------------- ---------- 10.7/14.5 MB 748.2 kB/s eta 0:00:06
#    ------------------------------ --------- 11.0/14.5 MB 752.6 kB/s eta 0:00:05
#    ------------------------------- -------- 11.3/14.5 MB 760.2 kB/s eta 0:00:05
#    ------------------------------- -------- 11.5/14.5 MB 768.3 kB/s eta 0:00:04
#    -------------------------------- ------- 11.8/14.5 MB 773.8 kB/s eta 0:00:04
#    -------------------------------- ------- 11.8/14.5 MB 773.8 kB/s eta 0:00:04
#    --------------------------------- ------ 12.3/14.5 MB 786.7 kB/s eta 0:00:03
#    ---------------------------------- ----- 12.6/14.5 MB 793.3 kB/s eta 0:00:03
#    ----------------------------------- ---- 12.8/14.5 MB 801.3 kB/s eta 0:00:03
#    ------------------------------------ --- 13.1/14.5 MB 809.1 kB/s eta 0:00:02
#    ------------------------------------- -- 13.6/14.5 MB 825.9 kB/s eta 0:00:02
#    -------------------------------------- - 13.9/14.5 MB 834.1 kB/s eta 0:00:01
#    -------------------------------------- - 14.2/14.5 MB 842.0 kB/s eta 0:00:01
#    ---------------------------------------- 14.5/14.5 MB 849.3 kB/s eta 0:00:00
# Downloading protobuf-3.20.3-cp310-cp310-win_amd64.whl (904 kB)
#    ---------------------------------------- 0.0/904.0 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/904.0 kB ? eta -:--:--
#    ----------------------- ---------------- 524.3/904.0 kB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 904.0/904.0 kB 1.7 MB/s eta 0:00:00
# Installing collected packages: protobuf, onnx, tf2onnx
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.6
#     Uninstalling protobuf-4.25.6:
#       Successfully uninstalled protobuf-4.25.6
# Successfully installed onnx-1.17.0 protobuf-3.20.3 tf2onnx-1.16.1
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\sadai\mediapipe\gesture_classifier_env\Lib\site-packages\google\~upb'.
#   You can safely remove it manually.

# %%
import tensorflow as tf
import tf2onnx

# Load the model
model = tf.keras.models.load_model("pose_classifier.h5")

# Convert to ONNX
onnx_model, _ = tf2onnx.convert.from_keras(model, output_path="pose_classifier.onnx")

print("Model converted to ONNX successfully!")
# Out:
# Model converted to ONNX successfully!

# %%
pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.44.1-py3-none-any.whl.metadata (8.9 kB)
# Collecting altair<6,>=4.0 (from streamlit)
#   Downloading altair-5.5.0-py3-none-any.whl.metadata (11 kB)
# Collecting blinker<2,>=1.0.0 (from streamlit)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from streamlit) (5.5.2)
# Collecting click<9,>=7.0 (from streamlit)
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from streamlit) (1.23.5)
# Collecting packaging<25,>=20 (from streamlit)
#   Using cached packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from streamlit) (2.2.3)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from streamlit) (11.2.1)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from streamlit) (4.25.6)
# Collecting pyarrow>=7.0 (from streamlit)
#   Downloading pyarrow-19.0.1-cp310-cp310-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from streamlit) (2.32.3)
# Collecting tenacity<10,>=8.1.0 (from streamlit)
#   Downloading tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting toml<2,>=0.10.1 (from streamlit)
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from streamlit) (4.13.2)
# Collecting watchdog<7,>=2.1.5 (from streamlit)
#   Downloading watchdog-6.0.0-py3-none-win_amd64.whl.metadata (44 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Using cached GitPython-3.1.44-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from streamlit) (6.4.2)
# Collecting jinja2 (from altair<6,>=4.0->streamlit)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting jsonschema>=3.0 (from altair<6,>=4.0->streamlit)
#   Using cached jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting narwhals>=1.14.2 (from altair<6,>=4.0->streamlit)
#   Downloading narwhals-1.35.0-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: colorama in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Using cached gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from requests<3,>=2.27->streamlit) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.1.31)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Using cached smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (25.3.0)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=3.0->altair<6,>=4.0->streamlit)
#   Using cached jsonschema_specifications-2024.10.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=3.0->altair<6,>=4.0->streamlit)
#   Using cached referencing-0.36.2-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=3.0->altair<6,>=4.0->streamlit)
#   Downloading rpds_py-0.24.0-cp310-cp310-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: six>=1.5 in c:\users\sadai\mediapipe\gesture_classifier_env\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Downloading streamlit-1.44.1-py3-none-any.whl (9.8 MB)
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.8 MB 2.4 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.0/9.8 MB 2.8 MB/s eta 0:00:04
#    ------- -------------------------------- 1.8/9.8 MB 3.0 MB/s eta 0:00:03
#    -------- ------------------------------- 2.1/9.8 MB 3.1 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.6/9.8 MB 2.5 MB/s eta 0:00:03
#    ------------ --------------------------- 3.1/9.8 MB 2.6 MB/s eta 0:00:03
#    ---------------- ----------------------- 3.9/9.8 MB 2.7 MB/s eta 0:00:03
#    ------------------ --------------------- 4.5/9.8 MB 2.8 MB/s eta 0:00:02
#    -------------------- ------------------- 5.0/9.8 MB 2.8 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.5/9.8 MB 2.7 MB/s eta 0:00:02
#    ------------------------ --------------- 6.0/9.8 MB 2.7 MB/s eta 0:00:02
#    ------------------------- -------------- 6.3/9.8 MB 2.5 MB/s eta 0:00:02
#    -------------------------- ------------- 6.6/9.8 MB 2.5 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.1/9.8 MB 2.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 7.3/9.8 MB 2.4 MB/s eta 0:00:02
#    -------------------------------- ------- 7.9/9.8 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.4/9.8 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------ --- 8.9/9.8 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.8 MB 2.3 MB/s eta 0:00:01
#    -------------------------------------- - 9.4/9.8 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 2.3 MB/s eta 0:00:00
# Downloading altair-5.5.0-py3-none-any.whl (731 kB)
#    ---------------------------------------- 0.0/731.2 kB ? eta -:--:--
#    -------------- ------------------------- 262.1/731.2 kB ? eta -:--:--
#    ---------------------------------------- 731.2/731.2 kB 2.0 MB/s eta 0:00:00
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
# Using cached GitPython-3.1.44-py3-none-any.whl (207 kB)
# Using cached packaging-24.2-py3-none-any.whl (65 kB)
# Downloading pyarrow-19.0.1-cp310-cp310-win_amd64.whl (25.3 MB)
#    ---------------------------------------- 0.0/25.3 MB ? eta -:--:--
#    ---------------------------------------- 0.3/25.3 MB ? eta -:--:--
#    - -------------------------------------- 0.8/25.3 MB 1.7 MB/s eta 0:00:15
#    - -------------------------------------- 1.0/25.3 MB 1.5 MB/s eta 0:00:16
#    -- ------------------------------------- 1.3/25.3 MB 1.5 MB/s eta 0:00:17
#    -- ------------------------------------- 1.6/25.3 MB 1.6 MB/s eta 0:00:15
#    --- ------------------------------------ 2.1/25.3 MB 1.6 MB/s eta 0:00:15
#    --- ------------------------------------ 2.4/25.3 MB 1.7 MB/s eta 0:00:14
#    ---- ----------------------------------- 2.6/25.3 MB 1.7 MB/s eta 0:00:14
#    ---- ----------------------------------- 3.1/25.3 MB 1.7 MB/s eta 0:00:14
#    ----- ---------------------------------- 3.4/25.3 MB 1.7 MB/s eta 0:00:14
#    ------ --------------------------------- 3.9/25.3 MB 1.7 MB/s eta 0:00:13
#    ------- -------------------------------- 4.5/25.3 MB 1.8 MB/s eta 0:00:12
#    ------- -------------------------------- 5.0/25.3 MB 1.8 MB/s eta 0:00:12
#    -------- ------------------------------- 5.2/25.3 MB 1.8 MB/s eta 0:00:11
#    --------- ------------------------------ 5.8/25.3 MB 1.8 MB/s eta 0:00:11
#    --------- ------------------------------ 6.0/25.3 MB 1.8 MB/s eta 0:00:11
#    --------- ------------------------------ 6.3/25.3 MB 1.8 MB/s eta 0:00:11
#    ---------- ----------------------------- 6.8/25.3 MB 1.8 MB/s eta 0:00:11
#    ----------- ---------------------------- 7.1/25.3 MB 1.8 MB/s eta 0:00:11
#    ----------- ---------------------------- 7.3/25.3 MB 1.8 MB/s eta 0:00:10
#    ------------ --------------------------- 7.9/25.3 MB 1.8 MB/s eta 0:00:10
#    ------------- -------------------------- 8.4/25.3 MB 1.8 MB/s eta 0:00:10
#    ------------- -------------------------- 8.7/25.3 MB 1.8 MB/s eta 0:00:10
#    -------------- ------------------------- 9.2/25.3 MB 1.8 MB/s eta 0:00:09
#    --------------- ------------------------ 9.7/25.3 MB 1.9 MB/s eta 0:00:09
#    --------------- ------------------------ 10.0/25.3 MB 1.9 MB/s eta 0:00:09
#    ---------------- ----------------------- 10.2/25.3 MB 1.8 MB/s eta 0:00:09
#    ---------------- ----------------------- 10.5/25.3 MB 1.8 MB/s eta 0:00:09
#    ----------------- ---------------------- 10.7/25.3 MB 1.8 MB/s eta 0:00:09
#    ----------------- ---------------------- 11.0/25.3 MB 1.8 MB/s eta 0:00:09
#    ----------------- ---------------------- 11.3/25.3 MB 1.8 MB/s eta 0:00:08
#    ------------------ --------------------- 11.5/25.3 MB 1.7 MB/s eta 0:00:08
#    ------------------ --------------------- 11.8/25.3 MB 1.7 MB/s eta 0:00:08
#    ------------------- -------------------- 12.1/25.3 MB 1.7 MB/s eta 0:00:08
#    ------------------- -------------------- 12.6/25.3 MB 1.7 MB/s eta 0:00:08
#    -------------------- ------------------- 12.8/25.3 MB 1.7 MB/s eta 0:00:08
#    --------------------- ------------------ 13.4/25.3 MB 1.7 MB/s eta 0:00:07
#    --------------------- ------------------ 13.9/25.3 MB 1.8 MB/s eta 0:00:07
#    ---------------------- ----------------- 14.4/25.3 MB 1.8 MB/s eta 0:00:07
#    ----------------------- ---------------- 14.7/25.3 MB 1.8 MB/s eta 0:00:07
#    ------------------------ --------------- 15.2/25.3 MB 1.8 MB/s eta 0:00:06
#    ------------------------ --------------- 15.5/25.3 MB 1.8 MB/s eta 0:00:06
#    ------------------------- -------------- 16.0/25.3 MB 1.8 MB/s eta 0:00:06
#    ------------------------- -------------- 16.3/25.3 MB 1.8 MB/s eta 0:00:06
#    -------------------------- ------------- 16.8/25.3 MB 1.8 MB/s eta 0:00:05
#    --------------------------- ------------ 17.3/25.3 MB 1.8 MB/s eta 0:00:05
#    ---------------------------- ----------- 17.8/25.3 MB 1.8 MB/s eta 0:00:05
#    ---------------------------- ----------- 18.1/25.3 MB 1.8 MB/s eta 0:00:04
#    ----------------------------- ---------- 18.6/25.3 MB 1.8 MB/s eta 0:00:04
#    ----------------------------- ---------- 18.9/25.3 MB 1.8 MB/s eta 0:00:04
#    ------------------------------ --------- 19.4/25.3 MB 1.8 MB/s eta 0:00:04
#    ------------------------------- -------- 19.7/25.3 MB 1.8 MB/s eta 0:00:04
#    ------------------------------- -------- 20.2/25.3 MB 1.8 MB/s eta 0:00:03
#    -------------------------------- ------- 20.7/25.3 MB 1.8 MB/s eta 0:00:03
#    --------------------------------- ------ 21.2/25.3 MB 1.8 MB/s eta 0:00:03
#    ---------------------------------- ----- 21.5/25.3 MB 1.8 MB/s eta 0:00:03
#    ---------------------------------- ----- 22.0/25.3 MB 1.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 22.5/25.3 MB 1.9 MB/s eta 0:00:02
#    ------------------------------------ --- 22.8/25.3 MB 1.9 MB/s eta 0:00:02
#    ------------------------------------ --- 23.1/25.3 MB 1.9 MB/s eta 0:00:02
#    ------------------------------------ --- 23.3/25.3 MB 1.8 MB/s eta 0:00:02
#    ------------------------------------- -- 23.9/25.3 MB 1.8 MB/s eta 0:00:01
#    -------------------------------------- - 24.1/25.3 MB 1.8 MB/s eta 0:00:01
#    -------------------------------------- - 24.6/25.3 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  24.9/25.3 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 25.3/25.3 MB 1.8 MB/s eta 0:00:00
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/6.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/6.9 MB 1.4 MB/s eta 0:00:05
#    ---- ----------------------------------- 0.8/6.9 MB 1.5 MB/s eta 0:00:05
#    ------- -------------------------------- 1.3/6.9 MB 1.6 MB/s eta 0:00:04
#    --------- ------------------------------ 1.6/6.9 MB 1.6 MB/s eta 0:00:04
#    ---------- ----------------------------- 1.8/6.9 MB 1.6 MB/s eta 0:00:04
#    ------------- -------------------------- 2.4/6.9 MB 1.6 MB/s eta 0:00:03
#    --------------- ------------------------ 2.6/6.9 MB 1.6 MB/s eta 0:00:03
#    ---------------- ----------------------- 2.9/6.9 MB 1.6 MB/s eta 0:00:03
#    ------------------ --------------------- 3.1/6.9 MB 1.6 MB/s eta 0:00:03
#    ------------------- -------------------- 3.4/6.9 MB 1.6 MB/s eta 0:00:03
#    ---------------------- ----------------- 3.9/6.9 MB 1.6 MB/s eta 0:00:02
#    ------------------------ --------------- 4.2/6.9 MB 1.6 MB/s eta 0:00:02
#    --------------------------- ------------ 4.7/6.9 MB 1.6 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.0/6.9 MB 1.6 MB/s eta 0:00:02
#    ------------------------------ --------- 5.2/6.9 MB 1.6 MB/s eta 0:00:02
#    --------------------------------- ------ 5.8/6.9 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------ --- 6.3/6.9 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------ --- 6.3/6.9 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------- -- 6.6/6.9 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 6.9/6.9 MB 1.6 MB/s eta 0:00:00
# Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading watchdog-6.0.0-py3-none-win_amd64.whl (79 kB)
# Using cached gitdb-4.0.12-py3-none-any.whl (62 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Downloading narwhals-1.35.0-py3-none-any.whl (325 kB)
# Using cached jsonschema_specifications-2024.10.1-py3-none-any.whl (18 kB)
# Using cached referencing-0.36.2-py3-none-any.whl (26 kB)
# Downloading rpds_py-0.24.0-cp310-cp310-win_amd64.whl (234 kB)
# Using cached smmap-5.0.2-py3-none-any.whl (24 kB)
# Installing collected packages: watchdog, toml, tenacity, smmap, rpds-py, pyarrow, packaging, narwhals, jinja2, click, blinker, referencing, pydeck, gitdb, jsonschema-specifications, gitpython, jsonschema, altair, streamlit
#   Attempting uninstall: packaging
#     Found existing installation: packaging 25.0
#     Uninstalling packaging-25.0:
#       Successfully uninstalled packaging-25.0
# Successfully installed altair-5.5.0 blinker-1.9.0 click-8.1.8 gitdb-4.0.12 gitpython-3.1.44 jinja2-3.1.6 jsonschema-4.23.0 jsonschema-specifications-2024.10.1 narwhals-1.35.0 packaging-24.2 pyarrow-19.0.1 pydeck-0.9.1 referencing-0.36.2 rpds-py-0.24.0 smmap-5.0.2 streamlit-1.44.1 tenacity-9.1.2 toml-0.10.2 watchdog-6.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st
import cv2
import numpy as np
import tensorflow as tf
import mediapipe as mp
import pickle

# Load model and label encoder
model = tf.keras.models.load_model("pose_classifier.h5")
with open('body_language.pkl', 'rb') as f:
    label_encoder = pickle.load(f)

st.title("Gesture/Emotion Classification")
st.text("Allow webcam to start prediction...")

# Setup MediaPipe
mp_holistic = mp.solutions.holistic
holistic = mp_holistic.Holistic(static_image_mode=False)

# Start webcam
frame_window = st.image([])
cap = cv2.VideoCapture(0)

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        st.write("Failed to grab frame")
        break

    # Convert to RGB
    img_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Process with MediaPipe
    result = holistic.process(img_rgb)

    # Collect landmarks
    landmarks = []

    def extract_landmarks(landmark_list):
        if landmark_list:
            for lm in landmark_list.landmark:
                landmarks.extend([lm.x, lm.y, lm.z])
        else:
            landmarks.extend([0.0, 0.0, 0.0] * 33)  # fill dummy if missing

    extract_landmarks(result.pose_landmarks)
    extract_landmarks(result.left_hand_landmarks)
    extract_landmarks(result.right_hand_landmarks)
    extract_landmarks(result.face_landmarks)

    if len(landmarks) == model.input_shape[1]:
        # Predict
        input_data = np.array(landmarks).reshape(1, -1)
        prediction = model.predict(input_data)
        pred_label = label_encoder.inverse_transform([np.argmax(prediction)])
        st.write(f"Prediction: {pred_label[0]}")
    else:
        st.write("Incomplete landmarks detected, skipping prediction...")

    # Display
    frame_window.image(img_rgb)

cap.release()
# Out:
# 2025-04-21 16:52:22.330 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:22.330 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:22.330 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:22.330 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:22.420 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:22.424 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:22.426 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:25.955 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:25.963 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:25.964 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:25.965 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:25.965 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.053 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.053 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.104 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.104 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.104 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.104 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.104 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.115 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.115 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.170 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.171 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.171 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.220 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.221 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.221 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.221 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.221 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.230 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.230 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.279 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.279 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.279 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.279 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.279 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.288 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.288 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.329 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.329 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.329 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.329 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.338 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.338 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.338 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.386 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.386 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.386 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.386 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.395 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.400 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.400 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.446 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.446 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.454 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.454 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.454 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.460 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.462 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.504 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.504 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.512 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.512 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.512 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.519 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.520 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.570 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.570 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.570 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.570 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.575 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.582 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.582 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.635 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.635 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.635 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.643 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.643 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.646 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.646 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.696 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.696 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.699 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.700 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.700 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.705 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.705 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.755 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.755 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.762 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.762 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.762 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.767 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.767 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.812 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.818 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.818 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.821 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.821 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.827 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.830 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.879 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.881 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.881 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.881 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.881 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.887 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.887 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.929 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.935 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.935 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.935 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.935 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.945 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.946 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.987 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.987 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.987 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.987 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.987 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.999 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:26.999 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.046 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.046 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.050 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.050 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.050 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.055 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.055 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.099 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.104 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.104 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.104 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.104 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.109 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.109 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.213 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.220 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.220 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.220 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.220 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.228 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.228 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.271 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.279 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.279 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.279 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.279 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.287 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.287 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.337 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.337 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.337 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.337 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.337 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.352 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.353 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.396 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.398 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.400 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.400 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.400 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.407 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.407 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.452 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.454 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.454 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.454 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.458 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.462 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.463 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.513 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.513 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.513 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.513 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.520 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.529 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.529 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.579 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.579 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.579 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.579 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.579 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.587 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.587 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.636 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.636 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.636 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.645 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.645 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.648 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.648 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.687 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.695 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.697 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.697 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.700 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.703 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.703 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.753 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.753 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.753 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.753 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.753 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.766 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.768 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.812 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.812 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.812 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.812 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.812 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.823 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.823 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.870 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.870 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.870 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.870 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.870 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.878 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.878 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.928 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.935 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.935 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.935 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.935 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.944 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.946 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.986 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.986 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.986 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.986 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.986 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.995 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:27.995 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.045 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.045 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.045 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.045 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.045 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.054 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.054 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.095 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.095 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.101 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.101 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.103 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.106 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.106 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.152 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.161 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.168 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.203 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.212 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.212 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.212 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.214 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.215 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.220 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.262 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.269 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.269 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.269 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.274 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.278 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.281 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.337 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.337 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.337 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.345 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.345 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.354 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.354 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.401 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.401 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.401 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.410 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.410 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.410 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.417 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.469 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.469 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.469 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.469 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.469 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.478 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.481 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.529 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.529 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.529 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.529 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.529 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.535 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.535 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.578 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.585 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.585 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.586 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.588 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.592 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.594 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.645 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.645 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.645 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.645 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.645 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.652 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.654 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.695 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.695 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.702 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.703 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.704 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.708 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.708 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.752 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.752 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.752 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.762 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.762 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.769 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.769 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.835 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.835 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.835 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.835 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.841 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.848 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.848 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.896 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.902 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.902 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.904 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.904 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.911 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.912 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.961 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.967 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.967 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.967 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.967 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.967 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:28.977 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:29.018 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:29.018 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:29.028 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:29.029 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:29.029 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:29.034 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:29.034 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:29.084 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:29.084 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:29.084 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:29.084 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:29.084 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:29.094 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:29.094 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:29.144 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:29.150 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:29.150 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:29.150 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:29.150 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:29.161 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:29.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:29.203 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:29.203 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
# 2025-04-21 16:52:42.141 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.198 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.198 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.198 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.198 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.204 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.213 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.213 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.275 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.275 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.275 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.275 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.284 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.292 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.292 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.372 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.372 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.372 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.372 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.372 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.384 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.384 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.448 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.448 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.448 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.454 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.456 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.462 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.465 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.529 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.529 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.529 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.529 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.529 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.537 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.537 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.589 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.589 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.589 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.589 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.596 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.604 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.605 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.673 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.673 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.673 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.678 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.679 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.686 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.687 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.739 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.739 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.739 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.747 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.747 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.755 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.755 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.805 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.805 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.805 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.811 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.812 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.815 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.815 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.860 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.860 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.860 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.866 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.866 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.874 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.874 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.929 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.929 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.929 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.934 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.934 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.941 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.941 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.989 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.989 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.989 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.989 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:42.989 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:43.001 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:43.001 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:43.063 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:43.063 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:43.063 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:43.068 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:43.068 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:43.075 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:43.075 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:43.138 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:43.139 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:43.139 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:43.139 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:43.142 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:43.146 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:43.146 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:43.189 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:43.189 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:43.189 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:43.202 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:43.202 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:43.208 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:43.212 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:43.255 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:43.263 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:43.263 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:43.266 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:43.266 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:43.273 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-21 16:52:43.273 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 34
#      31 img_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#      33 # Process with MediaPipe
# ---> 34 result = holistic.process(img_rgb)
#      36 # Collect landmarks
#      37 landmarks = []
#
# File ~\mediapipe\gesture_classifier_env\lib\site-packages\mediapipe\python\solutions\holistic.py:160, in Holistic.process(self, image)
#     136 def process(self, image: np.ndarray) -> NamedTuple:
#     137   """Processes an RGB image and returns the pose landmarks, left and right hand landmarks, and face landmarks on the most prominent person detected.
#     138
#     139   Args:
#    (...)
#     157          "enable_segmentation" is set to true.
#     158   """
# --> 160   results = super().process(input_data={'image': image})
#     161   if results.pose_landmarks:  # pytype: disable=attribute-error
#     162     for landmark in results.pose_landmarks.landmark:  # pytype: disable=attribute-error
#
# File ~\mediapipe\gesture_classifier_env\lib\site-packages\mediapipe\python\solution_base.py:340, in SolutionBase.process(self, input_data)
#     334   else:
#     335     self._graph.add_packet_to_input_stream(
#     336         stream=stream_name,
#     337         packet=self._make_packet(input_stream_type,
#     338                                  data).at(self._simulated_timestamp))
# --> 340 self._graph.wait_until_idle()
#     341 # Create a NamedTuple object where the field names are mapping to the graph
#     342 # output stream names.
#     343 if self._output_stream_type_info is None:
#
# KeyboardInterrupt:
